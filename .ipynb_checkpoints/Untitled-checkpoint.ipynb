# %%
import numpy as np
from scipy.optimize import linear_sum_assignment

def solve_wta(prob_matrix, target_values):
    m, n = prob_matrix.shape
    assert n == len(target_values), "Target values must match number of targets"

    # Compute effectiveness matrix E[i][j] = P[i][j] * V[j]
    effectiveness = prob_matrix * target_values

    # Since scipy solves minimization, convert to cost (maximize → minimize -E)
    cost_matrix = -effectiveness

    # Solve the assignment problem
    row_ind, col_ind = linear_sum_assignment(cost_matrix)

    total_effectiveness = effectiveness[row_ind, col_ind].sum()
    assignments = list(zip(row_ind, col_ind))

    return assignments, total_effectiveness

# %%
# Example: 3 weapons, 4 targets
P = np.array([
    [0.8, 0.5, 0.3, 0.2],
    [0.6, 0.9, 0.4, 0.1],
    [0.3, 0.2, 0.7, 0.5]
])

V = np.array([100, 80, 120, 60])  # Target values

assignments, score = solve_wta(P, V)

print("Assignments (weapon -> target):", assignments)
print("Total expected effectiveness:", score)
# Out:
# Assignments (weapon -> target): [(0, 0), (1, 1), (2, 2)]
# Total expected effectiveness: 236.0

# %%
def compute_effectiveness(weapons, targets):
    n = len(weapons)
    m = len(targets)

    prob_matrix = [[0.0 for _ in range(m)] for _ in range(n)]
    threat_levels = []

    # Compute threat level of each target
    for target in targets:
        distance = target["distance"]
        armor = target["armor"]
        threat = armor / max(distance, 1)
        threat_levels.append(threat)

    # Compute effectiveness of each weapon-target pair
    for i, weapon in enumerate(weapons):
        for j, target in enumerate(targets):
            distance = target["distance"]
            target_armor = target["armor"]

            if distance > weapon["range"]:
                prob_matrix[i][j] = 0.0
                continue

            range_modifier = max(0.1, 1 - (distance / weapon["range"]))  # closer = better
            effectiveness = (weapon["damage"] * range_modifier) / (target_armor + 1)
            prob_matrix[i][j] = min(1.0, effectiveness / 10)  # scale to [0,1]

    return prob_matrix, threat_levels

# %%
def greedy_weapon_target_assignment(prob_matrix):
    n = len(prob_matrix)
    m = len(prob_matrix[0])
    assignments = [-1] * n
    survival = [1.0] * m

    for i in range(n):
        best_target = -1
        best_score = -1
        for j in range(m):
            if prob_matrix[i][j] > best_score:
                best_score = prob_matrix[i][j]
                best_target = j
        assignments[i] = best_target
        if best_target != -1:
            survival[best_target] *= (1 - prob_matrix[i][best_target])

    print("\nAssignments:")
    for i in range(n):
        print(f"  Weapon {i} → Target {assignments[i]} (Effectiveness: {prob_matrix[i][assignments[i]]:.2f})")

    print("\nTarget Survival:")
    for j in range(m):
        print(f"  Target {j} survival ≈ {survival[j]:.3f} | kill ≈ {1 - survival[j]:.3f}")

    return assignments, survival

# %%
weapons = [
    {"id": 0, "range": 500, "impact": 80, "damage": 60, "type": "missile"},
    {"id": 1, "range": 1000, "impact": 60, "damage": 40, "type": "drone"},
    {"id": 2, "range": 700, "impact": 75, "damage": 70, "type": "artillery"}
]

targets = [
    {"id": 0, "distance": 450, "armor": 30},
    {"id": 1, "distance": 800, "armor": 60}
]

# Compute effectiveness and threat
prob_matrix, threat_levels = compute_effectiveness(weapons, targets)

# Show threat levels
print("\nTarget Threat Levels:")
for i, threat in enumerate(threat_levels):
    print(f"  Target {i}: Threat = {threat:.4f}")

# Solve assignment
assignments, survival = greedy_weapon_target_assignment(prob_matrix)
# Out:
# Target Threat Levels:
#   Target 0: Threat = 0.0667
#   Target 1: Threat = 0.0750
#
# Assignments:
#   Weapon 0 → Target 0 (Effectiveness: 0.02)
#   Weapon 1 → Target 0 (Effectiveness: 0.07)
#   Weapon 2 → Target 0 (Effectiveness: 0.08)
#
# Target Survival:
#   Target 0 survival ≈ 0.838 | kill ≈ 0.162
#   Target 1 survival ≈ 1.000 | kill ≈ 0.000

# %%
# --- Simulation with HP-based Kill System ---

# Weapon stats (range in meters, speed in m/s)
weapon_stats = {
    "missile":    {"damage": 70, "cooldown": 2, "range": 500_000, "speed": (300 * 1000) / 3600},
    "drone":      {"damage": 50, "cooldown": 1, "range": 1_000_000, "speed": (250 * 1000) / 3600},
    "artillery":  {"damage": 80, "cooldown": 3, "range": 700_000, "speed": (100 * 1000) / 3600},
    "cannon":     {"damage": 60, "cooldown": 2, "range": 400_000, "speed": (150 * 1000) / 3600},
    "laser":      {"damage": 45, "cooldown": 1, "range": 300_000, "speed": (500 * 1000) / 3600},
    "rocket":     {"damage": 65, "cooldown": 2, "range": 600_000, "speed": (350 * 1000) / 3600}
}

# Target stats (speed in m/s)
target_stats = {
    "tank":        {"armor": 30, "speed": (30 * 1000) / 3600},
    "bunker":      {"armor": 60, "speed": 0},
    "soldier":     {"armor": 10, "speed": (60 * 1000) / 3600},
    "radar":       {"armor": 15, "speed": 0},
    "aircraft":    {"armor": 25, "speed": (150 * 1000) / 3600},
    "command_post":{"armor": 40, "speed": 0}
}

# Initial weapons
weapons = [
    {"id": 0, "type": "missile", "ready_in": 0},
    {"id": 1, "type": "drone", "ready_in": 0},
    {"id": 2, "type": "artillery", "ready_in": 0},
    {"id": 3, "type": "laser", "ready_in": 0},
    {"id": 4, "type": "rocket", "ready_in": 0}
]

# Initial targets
targets = [
    {"id": 0, "type": "tank", "distance": 450_000},
    {"id": 1, "type": "bunker", "distance": 800_000},
    {"id": 2, "type": "radar", "distance": 350_000},
    {"id": 3, "type": "soldier", "distance": 900_000}
]

def compute_threat_levels(targets, k=100000):
    threat_levels = []
    for target in targets:
        armor = target_stats[target["type"]]["armor"]
        distance = max(target["distance"], 1)
        threat = (armor / distance) + (k / (distance ** 2))
        threat_levels.append(threat)
    return threat_levels

def compute_effectiveness(weapons, targets):
    prob_matrix = [[0.0 for _ in targets] for _ in weapons]
    for i, weapon in enumerate(weapons):
        wtype = weapon["type"]
        damage = weapon_stats[wtype]["damage"]
        w_range = weapon_stats[wtype]["range"]

        for j, target in enumerate(targets):
            ttype = target["type"]
            armor = target_stats[ttype]["armor"]
            distance = target["distance"]

            if distance > w_range:
                continue

            range_mod = max(0.1, 1 - (distance / w_range))
            effectiveness = (damage * range_mod) / (armor + 1)
            prob_matrix[i][j] = min(1.0, effectiveness / 2)
    return prob_matrix

def update_distances(targets):
    for target in targets:
        speed = target_stats[target["type"]]["speed"]
        target["distance"] = max(0, target["distance"] - speed)

def simulate_battle_hp(weapons, targets, max_rounds=1000):
    # Initialize HP: armor * 10 for each target
    hp = [target_stats[t["type"]]["armor"] * 10 for t in targets]
    for weapon in weapons:
        weapon["ready_in"] = 0

    for round_num in range(1, max_rounds + 1):
        print(f"\n--- Round {round_num} ---")
        update_distances(targets)
        threats = compute_threat_levels(targets)
        effects = compute_effectiveness(weapons, targets)
        assignments = [-1] * len(weapons)
        target_load = [0] * len(targets)

        for i, weapon in enumerate(weapons):
            if weapon["ready_in"] > 0:
                weapon["ready_in"] -= 1
                continue

            best, best_score = -1, -1
            for j, target in enumerate(targets):
                if hp[j] <= 0 or target["distance"] > weapon_stats[weapon["type"]]["range"] or target_load[j] >= 2:
                    continue
                score = effects[i][j] * threats[j]
                if score > best_score:
                    best, best_score = j, score

            if best != -1:
                assignments[i] = best
                target_load[best] += 1
                weapon["ready_in"] = weapon_stats[weapon["type"]]["cooldown"]

        for i, target_index in enumerate(assignments):
            if target_index != -1:
                wtype = weapons[i]["type"]
                damage = weapon_stats[wtype]["damage"]
                distance = targets[target_index]["distance"]
                w_range = weapon_stats[wtype]["range"]
                range_mod = max(0.1, 1 - (distance / w_range))
                actual_damage = damage * range_mod

                hp[target_index] -= actual_damage
                hp[target_index] = max(hp[target_index], 0)

                print(f"  Weapon {weapons[i]['id']} ({wtype}) → Target {target_index} ({targets[target_index]['type']}) | Damage: {actual_damage:.2f} | Target HP left: {hp[target_index]:.2f}")
            else:
                print(f"  Weapon {weapons[i]['id']} ({weapons[i]['type']}) is idle or cooling down.")

        for j, target in enumerate(targets):
            status = "Neutralized" if hp[j] <= 0 else f"HP = {hp[j]:.2f}, distance = {targets[j]['distance']:.2f} m"
            print(f"  Target {j} ({targets[j]['type']}): {status}")

        if all(h <= 0 for h in hp):
            print(f"\n✅ All targets neutralized in {round_num} rounds.")
            return hp

    print("\n⚠️ Simulation ended. Some targets are still alive.")
    return hp

# Run the simulation
simulate_battle_hp(weapons, targets)
# Out:
# --- Round 1 ---
#   Weapon 0 (missile) → Target 2 (radar) | Damage: 21.00 | Target HP left: 129.00
#   Weapon 1 (drone) → Target 2 (radar) | Damage: 32.50 | Target HP left: 96.50
#   Weapon 2 (artillery) → Target 0 (tank) | Damage: 28.57 | Target HP left: 271.43
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) → Target 0 (tank) | Damage: 16.25 | Target HP left: 255.18
#   Target 0 (tank): HP = 255.18, distance = 449991.67 m
#   Target 1 (bunker): HP = 600.00, distance = 800000.00 m
#   Target 2 (radar): HP = 96.50, distance = 350000.00 m
#   Target 3 (soldier): HP = 100.00, distance = 899983.33 m
#
# --- Round 2 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): HP = 255.18, distance = 449983.33 m
#   Target 1 (bunker): HP = 600.00, distance = 800000.00 m
#   Target 2 (radar): HP = 96.50, distance = 350000.00 m
#   Target 3 (soldier): HP = 100.00, distance = 899966.67 m
#
# --- Round 3 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 2 (radar) | Damage: 32.50 | Target HP left: 64.00
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): HP = 255.18, distance = 449975.00 m
#   Target 1 (bunker): HP = 600.00, distance = 800000.00 m
#   Target 2 (radar): HP = 64.00, distance = 350000.00 m
#   Target 3 (soldier): HP = 100.00, distance = 899950.00 m
#
# --- Round 4 ---
#   Weapon 0 (missile) → Target 2 (radar) | Damage: 21.00 | Target HP left: 43.00
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) → Target 2 (radar) | Damage: 27.08 | Target HP left: 15.92
#   Target 0 (tank): HP = 255.18, distance = 449966.67 m
#   Target 1 (bunker): HP = 600.00, distance = 800000.00 m
#   Target 2 (radar): HP = 15.92, distance = 350000.00 m
#   Target 3 (soldier): HP = 100.00, distance = 899933.33 m
#
# --- Round 5 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 2 (radar) | Damage: 32.50 | Target HP left: 0.00
#   Weapon 2 (artillery) → Target 2 (radar) | Damage: 40.00 | Target HP left: 0.00
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): HP = 255.18, distance = 449958.33 m
#   Target 1 (bunker): HP = 600.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 899916.67 m
#
# --- Round 6 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): HP = 255.18, distance = 449950.00 m
#   Target 1 (bunker): HP = 600.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 899900.00 m
#
# --- Round 7 ---
#   Weapon 0 (missile) → Target 0 (tank) | Damage: 7.01 | Target HP left: 248.17
#   Weapon 1 (drone) → Target 0 (tank) | Damage: 27.50 | Target HP left: 220.67
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): HP = 220.67, distance = 449941.67 m
#   Target 1 (bunker): HP = 600.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 899883.33 m
#
# --- Round 8 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) → Target 0 (tank) | Damage: 16.26 | Target HP left: 204.41
#   Target 0 (tank): HP = 204.41, distance = 449933.33 m
#   Target 1 (bunker): HP = 600.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 899866.67 m
#
# --- Round 9 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 0 (tank) | Damage: 27.50 | Target HP left: 176.90
#   Weapon 2 (artillery) → Target 0 (tank) | Damage: 28.58 | Target HP left: 148.32
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): HP = 148.32, distance = 449925.00 m
#   Target 1 (bunker): HP = 600.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 899850.00 m
#
# --- Round 10 ---
#   Weapon 0 (missile) → Target 0 (tank) | Damage: 7.01 | Target HP left: 141.31
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): HP = 141.31, distance = 449916.67 m
#   Target 1 (bunker): HP = 600.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 899833.33 m
#
# --- Round 11 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 0 (tank) | Damage: 27.50 | Target HP left: 113.81
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) → Target 0 (tank) | Damage: 16.26 | Target HP left: 97.55
#   Target 0 (tank): HP = 97.55, distance = 449908.33 m
#   Target 1 (bunker): HP = 600.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 899816.67 m
#
# --- Round 12 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): HP = 97.55, distance = 449900.00 m
#   Target 1 (bunker): HP = 600.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 899800.00 m
#
# --- Round 13 ---
#   Weapon 0 (missile) → Target 0 (tank) | Damage: 7.02 | Target HP left: 90.53
#   Weapon 1 (drone) → Target 0 (tank) | Damage: 27.51 | Target HP left: 63.03
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): HP = 63.03, distance = 449891.67 m
#   Target 1 (bunker): HP = 600.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 899783.33 m
#
# --- Round 14 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) → Target 0 (tank) | Damage: 28.58 | Target HP left: 34.44
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) → Target 0 (tank) | Damage: 16.26 | Target HP left: 18.18
#   Target 0 (tank): HP = 18.18, distance = 449883.33 m
#   Target 1 (bunker): HP = 600.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 899766.67 m
#
# --- Round 15 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 0 (tank) | Damage: 27.51 | Target HP left: 0.00
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 600.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 899750.00 m
#
# --- Round 16 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 600.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 899733.33 m
#
# --- Round 17 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 10.00 | Target HP left: 590.00
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 590.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 899716.67 m
#
# --- Round 18 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 590.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 899700.00 m
#
# --- Round 19 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 10.00 | Target HP left: 580.00
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 580.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 899683.33 m
#
# --- Round 20 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 580.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 899666.67 m
#
# --- Round 21 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 10.00 | Target HP left: 570.00
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 570.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 899650.00 m
#
# --- Round 22 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 570.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 899633.33 m
#
# --- Round 23 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 10.00 | Target HP left: 560.00
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 560.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 899616.67 m
#
# --- Round 24 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 560.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 899600.00 m
#
# --- Round 25 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 10.00 | Target HP left: 550.00
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 550.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 899583.33 m
#
# --- Round 26 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 550.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 899566.67 m
#
# --- Round 27 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 10.00 | Target HP left: 540.00
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 540.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 899550.00 m
#
# --- Round 28 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 540.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 899533.33 m
#
# --- Round 29 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 10.00 | Target HP left: 530.00
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 530.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 899516.67 m
#
# --- Round 30 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 530.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 899500.00 m
#
# --- Round 31 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 10.00 | Target HP left: 520.00
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 520.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 899483.33 m
#
# --- Round 32 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 520.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 899466.67 m
#
# --- Round 33 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 10.00 | Target HP left: 510.00
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 510.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 899450.00 m
#
# --- Round 34 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 510.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 899433.33 m
#
# --- Round 35 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 10.00 | Target HP left: 500.00
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 500.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 899416.67 m
#
# --- Round 36 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 500.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 899400.00 m
#
# --- Round 37 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 10.00 | Target HP left: 490.00
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 490.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 899383.33 m
#
# --- Round 38 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 490.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 899366.67 m
#
# --- Round 39 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 10.00 | Target HP left: 480.00
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 480.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 899350.00 m
#
# --- Round 40 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 480.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 899333.33 m
#
# --- Round 41 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 10.00 | Target HP left: 470.00
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 470.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 899316.67 m
#
# --- Round 42 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 470.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 899300.00 m
#
# --- Round 43 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 10.00 | Target HP left: 460.00
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 460.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 899283.33 m
#
# --- Round 44 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 460.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 899266.67 m
#
# --- Round 45 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 10.00 | Target HP left: 450.00
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 450.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 899250.00 m
#
# --- Round 46 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 450.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 899233.33 m
#
# --- Round 47 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 10.00 | Target HP left: 440.00
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 440.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 899216.67 m
#
# --- Round 48 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 440.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 899200.00 m
#
# --- Round 49 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 10.00 | Target HP left: 430.00
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 430.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 899183.33 m
#
# --- Round 50 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 430.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 899166.67 m
#
# --- Round 51 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 10.00 | Target HP left: 420.00
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 420.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 899150.00 m
#
# --- Round 52 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 420.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 899133.33 m
#
# --- Round 53 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 10.00 | Target HP left: 410.00
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 410.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 899116.67 m
#
# --- Round 54 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 410.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 899100.00 m
#
# --- Round 55 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 10.00 | Target HP left: 400.00
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 400.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 899083.33 m
#
# --- Round 56 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 400.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 899066.67 m
#
# --- Round 57 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 10.00 | Target HP left: 390.00
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 390.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 899050.00 m
#
# --- Round 58 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 390.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 899033.33 m
#
# --- Round 59 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 10.00 | Target HP left: 380.00
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 380.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 899016.67 m
#
# --- Round 60 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 380.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 899000.00 m
#
# --- Round 61 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 10.00 | Target HP left: 370.00
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 370.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 898983.33 m
#
# --- Round 62 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 370.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 898966.67 m
#
# --- Round 63 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 10.00 | Target HP left: 360.00
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 360.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 898950.00 m
#
# --- Round 64 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 360.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 898933.33 m
#
# --- Round 65 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 10.00 | Target HP left: 350.00
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 350.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 898916.67 m
#
# --- Round 66 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 350.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 898900.00 m
#
# --- Round 67 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 10.00 | Target HP left: 340.00
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 340.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 898883.33 m
#
# --- Round 68 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 340.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 898866.67 m
#
# --- Round 69 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 10.00 | Target HP left: 330.00
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 330.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 898850.00 m
#
# --- Round 70 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 330.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 898833.33 m
#
# --- Round 71 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 10.00 | Target HP left: 320.00
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 320.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 898816.67 m
#
# --- Round 72 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 320.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 898800.00 m
#
# --- Round 73 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 10.00 | Target HP left: 310.00
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 310.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 898783.33 m
#
# --- Round 74 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 310.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 898766.67 m
#
# --- Round 75 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 10.00 | Target HP left: 300.00
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 300.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 898750.00 m
#
# --- Round 76 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 300.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 898733.33 m
#
# --- Round 77 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 10.00 | Target HP left: 290.00
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 290.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 898716.67 m
#
# --- Round 78 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 290.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 898700.00 m
#
# --- Round 79 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 10.00 | Target HP left: 280.00
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 280.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 898683.33 m
#
# --- Round 80 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 280.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 898666.67 m
#
# --- Round 81 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 10.00 | Target HP left: 270.00
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 270.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 898650.00 m
#
# --- Round 82 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 270.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 898633.33 m
#
# --- Round 83 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 10.00 | Target HP left: 260.00
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 260.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 898616.67 m
#
# --- Round 84 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 260.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 898600.00 m
#
# --- Round 85 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 10.00 | Target HP left: 250.00
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 250.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 898583.33 m
#
# --- Round 86 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 250.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 898566.67 m
#
# --- Round 87 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 10.00 | Target HP left: 240.00
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 240.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 898550.00 m
#
# --- Round 88 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 240.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 898533.33 m
#
# --- Round 89 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 10.00 | Target HP left: 230.00
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 230.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 898516.67 m
#
# --- Round 90 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 230.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 898500.00 m
#
# --- Round 91 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 10.00 | Target HP left: 220.00
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 220.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 898483.33 m
#
# --- Round 92 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 220.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 898466.67 m
#
# --- Round 93 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 10.00 | Target HP left: 210.00
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 210.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 898450.00 m
#
# --- Round 94 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 210.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 898433.33 m
#
# --- Round 95 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 10.00 | Target HP left: 200.00
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 200.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 898416.67 m
#
# --- Round 96 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 200.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 898400.00 m
#
# --- Round 97 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 10.00 | Target HP left: 190.00
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 190.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 898383.33 m
#
# --- Round 98 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 190.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 898366.67 m
#
# --- Round 99 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 10.00 | Target HP left: 180.00
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 180.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 898350.00 m
#
# --- Round 100 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 180.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 898333.33 m
#
# --- Round 101 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 10.00 | Target HP left: 170.00
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 170.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 898316.67 m
#
# --- Round 102 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 170.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 898300.00 m
#
# --- Round 103 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 10.00 | Target HP left: 160.00
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 160.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 898283.33 m
#
# --- Round 104 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 160.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 898266.67 m
#
# --- Round 105 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 10.00 | Target HP left: 150.00
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 150.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 898250.00 m
#
# --- Round 106 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 150.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 100.00, distance = 898233.33 m
#
# --- Round 107 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 10.00 | Target HP left: 140.00
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 140.00, distance = 800000.00 m
# ...
#   Target 1 (bunker): Neutralized
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 94.88, distance = 897683.33 m
#
# --- Round 140 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): Neutralized
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 94.88, distance = 897666.67 m
#
# --- Round 141 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 3 (soldier) | Damage: 5.12 | Target HP left: 89.77
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): Neutralized
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 89.77, distance = 897650.00 m
#
# --- Round 142 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): Neutralized
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 89.77, distance = 897633.33 m
#
# --- Round 143 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 3 (soldier) | Damage: 5.12 | Target HP left: 84.65
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): Neutralized
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 84.65, distance = 897616.67 m
#
# --- Round 144 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): Neutralized
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 84.65, distance = 897600.00 m
#
# --- Round 145 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 3 (soldier) | Damage: 5.12 | Target HP left: 79.53
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): Neutralized
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 79.53, distance = 897583.33 m
#
# --- Round 146 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): Neutralized
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 79.53, distance = 897566.67 m
#
# --- Round 147 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 3 (soldier) | Damage: 5.12 | Target HP left: 74.40
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): Neutralized
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 74.40, distance = 897550.00 m
#
# --- Round 148 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): Neutralized
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 74.40, distance = 897533.33 m
#
# --- Round 149 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 3 (soldier) | Damage: 5.12 | Target HP left: 69.28
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): Neutralized
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 69.28, distance = 897516.67 m
#
# --- Round 150 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): Neutralized
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 69.28, distance = 897500.00 m
#
# --- Round 151 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 3 (soldier) | Damage: 5.13 | Target HP left: 64.15
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): Neutralized
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 64.15, distance = 897483.33 m
#
# --- Round 152 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): Neutralized
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 64.15, distance = 897466.67 m
#
# --- Round 153 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 3 (soldier) | Damage: 5.13 | Target HP left: 59.03
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): Neutralized
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 59.03, distance = 897450.00 m
#
# --- Round 154 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): Neutralized
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 59.03, distance = 897433.33 m
#
# --- Round 155 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 3 (soldier) | Damage: 5.13 | Target HP left: 53.90
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): Neutralized
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 53.90, distance = 897416.67 m
#
# --- Round 156 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): Neutralized
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 53.90, distance = 897400.00 m
#
# --- Round 157 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 3 (soldier) | Damage: 5.13 | Target HP left: 48.77
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): Neutralized
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 48.77, distance = 897383.33 m
#
# --- Round 158 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): Neutralized
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 48.77, distance = 897366.67 m
#
# --- Round 159 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 3 (soldier) | Damage: 5.13 | Target HP left: 43.63
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): Neutralized
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 43.63, distance = 897350.00 m
#
# --- Round 160 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): Neutralized
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 43.63, distance = 897333.33 m
#
# --- Round 161 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 3 (soldier) | Damage: 5.13 | Target HP left: 38.50
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): Neutralized
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 38.50, distance = 897316.67 m
#
# --- Round 162 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): Neutralized
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 38.50, distance = 897300.00 m
#
# --- Round 163 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 3 (soldier) | Damage: 5.14 | Target HP left: 33.36
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): Neutralized
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 33.36, distance = 897283.33 m
#
# --- Round 164 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): Neutralized
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 33.36, distance = 897266.67 m
#
# --- Round 165 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 3 (soldier) | Damage: 5.14 | Target HP left: 28.23
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): Neutralized
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 28.23, distance = 897250.00 m
#
# --- Round 166 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): Neutralized
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 28.23, distance = 897233.33 m
#
# --- Round 167 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 3 (soldier) | Damage: 5.14 | Target HP left: 23.09
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): Neutralized
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 23.09, distance = 897216.67 m
#
# --- Round 168 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): Neutralized
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 23.09, distance = 897200.00 m
#
# --- Round 169 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 3 (soldier) | Damage: 5.14 | Target HP left: 17.95
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): Neutralized
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 17.95, distance = 897183.33 m
#
# --- Round 170 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): Neutralized
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 17.95, distance = 897166.67 m
#
# --- Round 171 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 3 (soldier) | Damage: 5.14 | Target HP left: 12.80
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): Neutralized
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 12.80, distance = 897150.00 m
#
# --- Round 172 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): Neutralized
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 12.80, distance = 897133.33 m
#
# --- Round 173 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 3 (soldier) | Damage: 5.14 | Target HP left: 7.66
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): Neutralized
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 7.66, distance = 897116.67 m
#
# --- Round 174 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): Neutralized
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 7.66, distance = 897100.00 m
#
# --- Round 175 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 3 (soldier) | Damage: 5.15 | Target HP left: 2.51
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): Neutralized
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 2.51, distance = 897083.33 m
#
# --- Round 176 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): Neutralized
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 2.51, distance = 897066.67 m
#
# --- Round 177 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 3 (soldier) | Damage: 5.15 | Target HP left: 0.00
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): Neutralized
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): Neutralized
#
# ✅ All targets neutralized in 177 rounds.
# [0, 0, 0, 0]

# %%
# Weapon stats (range in meters, speed in m/s)
weapon_stats = {
    "missile":    {"damage": 60, "cooldown": 2, "range": 500_000, "speed": (300 * 1000) / 3600},
    "drone":      {"damage": 40, "cooldown": 1, "range": 1_000_000, "speed": (250 * 1000) / 3600},
    "artillery":  {"damage": 70, "cooldown": 3, "range": 700_000, "speed": (100 * 1000) / 3600},
    "cannon":     {"damage": 50, "cooldown": 2, "range": 400_000, "speed": (150 * 1000) / 3600},
    "laser":      {"damage": 35, "cooldown": 1, "range": 300_000, "speed": (500 * 1000) / 3600},
    "rocket":     {"damage": 55, "cooldown": 2, "range": 600_000, "speed": (350 * 1000) / 3600}
}

# Target stats (speed in m/s)
target_stats = {
    "tank":        {"armor": 30, "speed": (30 * 1000) / 3600},
    "bunker":      {"armor": 60, "speed": 0},
    "soldier":     {"armor": 10, "speed": (60 * 1000) / 3600},
    "radar":       {"armor": 15, "speed": 0}
}

# Initial weapons (added one more missile)
weapons = [
    {"id": 0, "type": "missile", "ready_in": 0},
    {"id": 1, "type": "drone", "ready_in": 0},
    {"id": 2, "type": "artillery", "ready_in": 0},
    {"id": 3, "type": "laser", "ready_in": 0},
    {"id": 4, "type": "rocket", "ready_in": 0}
]

# Initial targets
targets = [
    {"id": 0, "type": "tank", "distance": 450_000},
    {"id": 1, "type": "bunker", "distance": 800_000},
    {"id": 2, "type": "radar", "distance": 350_000},
    {"id": 3, "type": "soldier", "distance": 900_000}
]

def update_distances(targets):
    for target in targets:
        speed = target_stats[target["type"]]["speed"]
        target["distance"] = max(0, target["distance"] - speed)

def simulate_battle_detailed(weapons, targets, max_rounds=1000):
    hp = [target_stats[t["type"]]["armor"] * 10 for t in targets]
    for weapon in weapons:
        weapon["ready_in"] = 0

    for round_num in range(1, max_rounds + 1):
        print(f"\n--- Round {round_num} ---")
        update_distances(targets)
        assignments = [-1] * len(weapons)

        for i, weapon in enumerate(weapons):
            if weapon["ready_in"] > 0:
                weapon["ready_in"] -= 1
                continue

            wtype = weapon["type"]
            damage = weapon_stats[wtype]["damage"]
            w_range = weapon_stats[wtype]["range"]

            best_target = -1
            best_score = -1

            for j, target in enumerate(targets):
                if hp[j] <= 0 or target["distance"] > w_range:
                    continue

                range_mod = 1 / (1 + (target["distance"] / w_range))
                effective_damage = damage * range_mod
                score = effective_damage / (hp[j] + 1)

                if score > best_score:
                    best_score = score
                    best_target = j

            if best_target != -1:
                assignments[i] = best_target
                weapon["ready_in"] = weapon_stats[wtype]["cooldown"]

        for i, target_index in enumerate(assignments):
            if target_index != -1:
                wtype = weapons[i]["type"]
                damage = weapon_stats[wtype]["damage"]
                distance = targets[target_index]["distance"]
                w_range = weapon_stats[wtype]["range"]
                range_mod = 1 / (1 + (distance / w_range))
                actual_damage = damage * range_mod

                hp[target_index] -= actual_damage
                hp[target_index] = max(hp[target_index], 0)

                print(f"  Weapon {weapons[i]['id']} ({wtype}) → Target {target_index} ({targets[target_index]['type']}) | Damage: {actual_damage:.2f} | Target HP left: {hp[target_index]:.2f}")
            else:
                print(f"  Weapon {weapons[i]['id']} ({weapons[i]['type']}) is idle or cooling down.")

        for j, target in enumerate(targets):
            status = "Neutralized" if hp[j] <= 0 else f"HP = {hp[j]:.2f}, distance = {targets[j]['distance']:.2f} m"
            print(f"  Target {j} ({targets[j]['type']}): {status}")

        if all(h <= 1e-2 for h in hp):
            print(f"\n✅ All targets neutralized in {round_num} rounds.")
            return round_num

    print("\n⚠️ Simulation ended. Some targets are still alive.")
    return -1

simulate_battle_detailed(weapons.copy(), [t.copy() for t in targets])
# Out:
# --- Round 1 ---
#   Weapon 0 (missile) → Target 2 (radar) | Damage: 35.29 | Target HP left: 114.71
#   Weapon 1 (drone) → Target 3 (soldier) | Damage: 21.05 | Target HP left: 78.95
#   Weapon 2 (artillery) → Target 2 (radar) | Damage: 46.67 | Target HP left: 68.04
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) → Target 2 (radar) | Damage: 34.74 | Target HP left: 33.30
#   Target 0 (tank): HP = 300.00, distance = 449991.67 m
#   Target 1 (bunker): HP = 600.00, distance = 800000.00 m
#   Target 2 (radar): HP = 33.30, distance = 350000.00 m
#   Target 3 (soldier): HP = 78.95, distance = 899983.33 m
#
# --- Round 2 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): HP = 300.00, distance = 449983.33 m
#   Target 1 (bunker): HP = 600.00, distance = 800000.00 m
#   Target 2 (radar): HP = 33.30, distance = 350000.00 m
#   Target 3 (soldier): HP = 78.95, distance = 899966.67 m
#
# --- Round 3 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 2 (radar) | Damage: 29.63 | Target HP left: 3.67
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): HP = 300.00, distance = 449975.00 m
#   Target 1 (bunker): HP = 600.00, distance = 800000.00 m
#   Target 2 (radar): HP = 3.67, distance = 350000.00 m
#   Target 3 (soldier): HP = 78.95, distance = 899950.00 m
#
# --- Round 4 ---
#   Weapon 0 (missile) → Target 2 (radar) | Damage: 35.29 | Target HP left: 0.00
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) → Target 2 (radar) | Damage: 34.74 | Target HP left: 0.00
#   Target 0 (tank): HP = 300.00, distance = 449966.67 m
#   Target 1 (bunker): HP = 600.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 78.95, distance = 899933.33 m
#
# --- Round 5 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 3 (soldier) | Damage: 21.05 | Target HP left: 57.89
#   Weapon 2 (artillery) → Target 0 (tank) | Damage: 42.61 | Target HP left: 257.39
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): HP = 257.39, distance = 449958.33 m
#   Target 1 (bunker): HP = 600.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 57.89, distance = 899916.67 m
#
# --- Round 6 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): HP = 257.39, distance = 449950.00 m
#   Target 1 (bunker): HP = 600.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 57.89, distance = 899900.00 m
#
# --- Round 7 ---
#   Weapon 0 (missile) → Target 0 (tank) | Damage: 31.58 | Target HP left: 225.81
#   Weapon 1 (drone) → Target 3 (soldier) | Damage: 21.05 | Target HP left: 36.84
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) → Target 0 (tank) | Damage: 31.43 | Target HP left: 194.38
#   Target 0 (tank): HP = 194.38, distance = 449941.67 m
#   Target 1 (bunker): HP = 600.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 36.84, distance = 899883.33 m
#
# --- Round 8 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): HP = 194.38, distance = 449933.33 m
#   Target 1 (bunker): HP = 600.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 36.84, distance = 899866.67 m
#
# --- Round 9 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 3 (soldier) | Damage: 21.05 | Target HP left: 15.79
#   Weapon 2 (artillery) → Target 0 (tank) | Damage: 42.61 | Target HP left: 151.77
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): HP = 151.77, distance = 449925.00 m
#   Target 1 (bunker): HP = 600.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 15.79, distance = 899850.00 m
#
# --- Round 10 ---
#   Weapon 0 (missile) → Target 0 (tank) | Damage: 31.58 | Target HP left: 120.19
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) → Target 0 (tank) | Damage: 31.43 | Target HP left: 88.75
#   Target 0 (tank): HP = 88.75, distance = 449916.67 m
#   Target 1 (bunker): HP = 600.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): HP = 15.79, distance = 899833.33 m
#
# --- Round 11 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 3 (soldier) | Damage: 21.05 | Target HP left: 0.00
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): HP = 88.75, distance = 449908.33 m
#   Target 1 (bunker): HP = 600.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): Neutralized
#
# --- Round 12 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): HP = 88.75, distance = 449900.00 m
#   Target 1 (bunker): HP = 600.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): Neutralized
#
# --- Round 13 ---
#   Weapon 0 (missile) → Target 0 (tank) | Damage: 31.58 | Target HP left: 57.17
#   Weapon 1 (drone) → Target 0 (tank) | Damage: 27.59 | Target HP left: 29.58
#   Weapon 2 (artillery) → Target 0 (tank) | Damage: 42.61 | Target HP left: 0.00
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) → Target 0 (tank) | Damage: 31.43 | Target HP left: 0.00
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 600.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): Neutralized
#
# --- Round 14 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 600.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): Neutralized
#
# --- Round 15 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 22.22 | Target HP left: 577.78
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 577.78, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): Neutralized
#
# --- Round 16 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 577.78, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): Neutralized
#
# --- Round 17 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 22.22 | Target HP left: 555.56
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 555.56, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): Neutralized
#
# --- Round 18 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 555.56, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): Neutralized
#
# --- Round 19 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 22.22 | Target HP left: 533.33
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 533.33, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): Neutralized
#
# --- Round 20 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 533.33, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): Neutralized
#
# --- Round 21 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 22.22 | Target HP left: 511.11
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 511.11, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): Neutralized
#
# --- Round 22 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 511.11, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): Neutralized
#
# --- Round 23 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 22.22 | Target HP left: 488.89
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 488.89, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): Neutralized
#
# --- Round 24 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 488.89, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): Neutralized
#
# --- Round 25 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 22.22 | Target HP left: 466.67
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 466.67, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): Neutralized
#
# --- Round 26 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 466.67, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): Neutralized
#
# --- Round 27 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 22.22 | Target HP left: 444.44
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 444.44, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): Neutralized
#
# --- Round 28 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 444.44, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): Neutralized
#
# --- Round 29 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 22.22 | Target HP left: 422.22
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 422.22, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): Neutralized
#
# --- Round 30 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 422.22, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): Neutralized
#
# --- Round 31 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 22.22 | Target HP left: 400.00
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 400.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): Neutralized
#
# --- Round 32 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 400.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): Neutralized
#
# --- Round 33 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 22.22 | Target HP left: 377.78
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 377.78, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): Neutralized
#
# --- Round 34 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 377.78, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): Neutralized
#
# --- Round 35 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 22.22 | Target HP left: 355.56
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 355.56, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): Neutralized
#
# --- Round 36 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 355.56, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): Neutralized
#
# --- Round 37 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 22.22 | Target HP left: 333.33
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 333.33, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): Neutralized
#
# --- Round 38 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 333.33, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): Neutralized
#
# --- Round 39 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 22.22 | Target HP left: 311.11
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 311.11, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): Neutralized
#
# --- Round 40 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 311.11, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): Neutralized
#
# --- Round 41 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 22.22 | Target HP left: 288.89
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 288.89, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): Neutralized
#
# --- Round 42 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 288.89, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): Neutralized
#
# --- Round 43 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 22.22 | Target HP left: 266.67
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 266.67, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): Neutralized
#
# --- Round 44 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 266.67, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): Neutralized
#
# --- Round 45 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 22.22 | Target HP left: 244.44
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 244.44, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): Neutralized
#
# --- Round 46 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 244.44, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): Neutralized
#
# --- Round 47 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 22.22 | Target HP left: 222.22
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 222.22, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): Neutralized
#
# --- Round 48 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 222.22, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): Neutralized
#
# --- Round 49 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 22.22 | Target HP left: 200.00
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 200.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): Neutralized
#
# --- Round 50 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 200.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): Neutralized
#
# --- Round 51 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 22.22 | Target HP left: 177.78
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 177.78, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): Neutralized
#
# --- Round 52 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 177.78, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): Neutralized
#
# --- Round 53 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 22.22 | Target HP left: 155.56
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 155.56, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): Neutralized
#
# --- Round 54 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 155.56, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): Neutralized
#
# --- Round 55 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 22.22 | Target HP left: 133.33
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 133.33, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): Neutralized
#
# --- Round 56 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 133.33, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): Neutralized
#
# --- Round 57 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 22.22 | Target HP left: 111.11
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 111.11, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): Neutralized
#
# --- Round 58 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 111.11, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): Neutralized
#
# --- Round 59 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 22.22 | Target HP left: 88.89
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 88.89, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): Neutralized
#
# --- Round 60 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 88.89, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): Neutralized
#
# --- Round 61 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 22.22 | Target HP left: 66.67
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 66.67, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): Neutralized
#
# --- Round 62 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 66.67, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): Neutralized
#
# --- Round 63 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 22.22 | Target HP left: 44.44
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 44.44, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): Neutralized
#
# --- Round 64 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 44.44, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): Neutralized
#
# --- Round 65 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 22.22 | Target HP left: 22.22
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 22.22, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): Neutralized
#
# --- Round 66 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 22.22, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): Neutralized
#
# --- Round 67 ---
#   Weapon 0 (missile) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (bunker) | Damage: 22.22 | Target HP left: 0.00
#   Weapon 2 (artillery) is idle or cooling down.
#   Weapon 3 (laser) is idle or cooling down.
#   Weapon 4 (rocket) is idle or cooling down.
#   Target 0 (tank): Neutralized
#   Target 1 (bunker): HP = 0.00, distance = 800000.00 m
#   Target 2 (radar): Neutralized
#   Target 3 (soldier): Neutralized
#
# ✅ All targets neutralized in 67 rounds.
# 67

# %%
# --- Simulation with Selected Weapons & Targets ---





def compute_threat_levels(targets, k=100000):
    threat_levels = []
    for target in targets:
        armor = target_stats[target["type"]]["armor"]
        distance = max(target["distance"], 1)
        threat = (armor / distance) + (k / (distance ** 2))
        threat_levels.append(threat)
    return threat_levels

def compute_effectiveness(weapons, targets):
    prob_matrix = [[0.0 for _ in targets] for _ in weapons]
    for i, weapon in enumerate(weapons):
        wtype = weapon["type"]
        damage = weapon_stats[wtype]["damage"]
        w_range = weapon_stats[wtype]["range"]

        for j, target in enumerate(targets):
            ttype = target["type"]
            armor = target_stats[ttype]["armor"]
            distance = target["distance"]

            if distance > w_range:
                continue

            range_mod = max(0.1, 1 - (distance / w_range))
            effectiveness = (damage * range_mod) / (armor + 1)
            prob_matrix[i][j] = min(1.0, effectiveness / 2)
    return prob_matrix

def update_distances(targets):
    for target in targets:
        speed = target_stats[target["type"]]["speed"]
        target["distance"] = max(0, target["distance"] - speed)

def simulate_battle_hp(weapons, targets, max_rounds=1000):
    hp = [target_stats[t["type"]]["armor"] * 10 for t in targets]
    for weapon in weapons:
        weapon["ready_in"] = 0

    for round_num in range(1, max_rounds + 1):
        print(f"\n--- Round {round_num} ---")
        update_distances(targets)
        threats = compute_threat_levels(targets)
        effects = compute_effectiveness(weapons, targets)
        assignments = [-1] * len(weapons)
        target_load = [0] * len(targets)

        for i, weapon in enumerate(weapons):
            if weapon["ready_in"] > 0:
                weapon["ready_in"] -= 1
                continue

            best, best_score = -1, -1
            for j, target in enumerate(targets):
                if hp[j] <= 0 or target["distance"] > weapon_stats[weapon["type"]]["range"] or target_load[j] >= 2:
                    continue
                score = effects[i][j] * threats[j]
                if score > best_score:
                    best, best_score = j, score

            if best != -1:
                assignments[i] = best
                target_load[best] += 1
                weapon["ready_in"] = weapon_stats[weapon["type"]]["cooldown"]

        for i, target_index in enumerate(assignments):
            if target_index != -1:
                wtype = weapons[i]["type"]
                damage = weapon_stats[wtype]["damage"]
                distance = targets[target_index]["distance"]
                w_range = weapon_stats[wtype]["range"]
                range_mod = max(0.1, 1 - (distance / w_range))
                actual_damage = damage * range_mod

                hp[target_index] -= actual_damage
                hp[target_index] = max(hp[target_index], 0)

                print(f"  Weapon {weapons[i]['id']} ({wtype}) → Target {target_index} ({targets[target_index]['type']}) | Damage: {actual_damage:.2f} | Target HP left: {hp[target_index]:.2f}")
            else:
                print(f"  Weapon {weapons[i]['id']} ({weapons[i]['type']}) is idle or cooling down.")

        for j, target in enumerate(targets):
            status = "Neutralized" if hp[j] <= 0 else f"HP = {hp[j]:.2f}, distance = {targets[j]['distance']:.2f} m"
            print(f"  Target {j} ({targets[j]['type']}): {status}")

        if all(h <= 0 for h in hp):
            print(f"\n✅ All targets neutralized in {round_num} rounds.")
            return hp

    print("\n⚠️ Simulation ended. Some targets are still alive.")
    return hp

# 🔄 Run the simulation

# %%
# --- Weapon-Target Simulation Framework by Scenario ---
import random

# Weapon definitions per scenario (subset of best types)
scenario_weapons = {
    "urban_battlefield": ["artillery", "drone", "tankgun"],
    "airfield_defense": ["missile", "sam", "drone"],
    "convoy_ambush": ["artillery", "drone", "missile"],
    "mountain_warfare": ["artillery", "drone", "missile", "tankgun"],
    "naval_battle": ["torpedo", "missile", "drone", "sam"],
    "desert_conflict": ["missile", "artillery", "drone", "sam", "tankgun"],
    "jungle_ambush": ["drone", "missile", "artillery"]
}

scenario_targets = {
    "urban_battlefield": ["tank", "infantry", "radar"],
    "airfield_defense": ["aircraft", "radar", "commandcenter"],
    "convoy_ambush": ["truck", "tank", "commandcenter"],
    "mountain_warfare": ["snipernest", "tank", "infantry", "radar", "supplydepot"],
    "naval_battle": ["destroyer", "submarine", "aircraft", "radar", "supplyship"],
    "desert_conflict": ["tank", "infantry", "truck", "commandcenter", "radar"],
    "jungle_ambush": ["infantry", "snipernest", "commandcenter", "radar"]
}

# Stats for weapons
weapon_stats = {
    "missile":    {"damage": 75, "cooldown": 2, "range": 600_000, "speed": (350 * 1000) / 3600},
    "drone":      {"damage": 45, "cooldown": 1, "range": 800_000, "speed": (250 * 1000) / 3600},
    "artillery":  {"damage": 90, "cooldown": 3, "range": 700_000, "speed": (120 * 1000) / 3600},
    "sam":        {"damage": 60, "cooldown": 2, "range": 500_000, "speed": (400 * 1000) / 3600},
    "tankgun":    {"damage": 50, "cooldown": 2, "range": 300_000, "speed": (100 * 1000) / 3600},
    "torpedo":    {"damage": 100, "cooldown": 4, "range": 400_000, "speed": (80 * 1000) / 3600},
}

# Stats for targets
target_stats = {
    "tank":         {"armor": 35, "speed": (40 * 1000) / 3600},
    "infantry":     {"armor": 10, "speed": (60 * 1000) / 3600},
    "radar":        {"armor": 15, "speed": 0},
    "aircraft":     {"armor": 20, "speed": (180 * 1000) / 3600},
    "truck":        {"armor": 12, "speed": (50 * 1000) / 3600},
    "commandcenter":{"armor": 50, "speed": 0},
    "submarine":    {"armor": 40, "speed": (25 * 1000) / 3600},
    "destroyer":    {"armor": 45, "speed": (30 * 1000) / 3600},
    "supplyship":   {"armor": 30, "speed": (20 * 1000) / 3600},
    "snipernest":   {"armor": 20, "speed": 0},
    "supplydepot":  {"armor": 25, "speed": 0}
}

# Core Functions (same as before): compute_threat_levels, compute_effectiveness, update_distances
# ... and simulate_battle_hp

# Reuse the simulation engine code (to keep things modular)
# You can copy-paste simulate_battle_hp, compute_threat_levels, compute_effectiveness, update_distances from the previous reply above this

# Create scenario-based weapons/targets
def create_scenario_assets(scenario):
    weapons = []
    for i, w in enumerate(scenario_weapons[scenario]):
        weapons.append({"id": i, "type": w, "ready_in": 0})

    targets = []
    for i, t in enumerate(scenario_targets[scenario]):
        targets.append({
            "id": i,
            "type": t,
            "distance": random.randint(200_000, 700_000)
        })

    return weapons, targets

# 🔽 USER INPUT STEP
available_scenarios = list(scenario_weapons.keys())
print("\nAvailable Scenarios:")
for s in available_scenarios:
    print(f"  - {s}")

selected_scenario = input("\nEnter scenario name to simulate: ").strip().lower()
if selected_scenario not in scenario_weapons:
    print("❌ Invalid scenario. Please rerun and pick from the list.")
else:
    weapons, targets = create_scenario_assets(selected_scenario)
    simulate_battle_hp(weapons, targets)
# Out:
# Available Scenarios:
#   - urban_battlefield
#   - airfield_defense
#   - convoy_ambush
#   - mountain_warfare
#   - naval_battle
#   - desert_conflict
#   - jungle_ambush
# Enter scenario name to simulate:  convoy_ambush
# --- Round 1 ---
#   Weapon 0 (artillery) → Target 0 (truck) | Damage: 45.55 | Target HP left: 74.45
#   Weapon 1 (drone) → Target 0 (truck) | Damage: 25.55 | Target HP left: 48.89
#   Weapon 2 (missile) → Target 2 (commandcenter) | Damage: 18.34 | Target HP left: 481.66
#   Target 0 (truck): HP = 48.89, distance = 345697.11 m
#   Target 1 (tank): HP = 350.00, distance = 534151.89 m
#   Target 2 (commandcenter): HP = 481.66, distance = 453283.00 m
#
# --- Round 2 ---
#   Weapon 0 (artillery) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (missile) is idle or cooling down.
#   Target 0 (truck): HP = 48.89, distance = 345683.22 m
#   Target 1 (tank): HP = 350.00, distance = 534140.78 m
#   Target 2 (commandcenter): HP = 481.66, distance = 453283.00 m
#
# --- Round 3 ---
#   Weapon 0 (artillery) is idle or cooling down.
#   Weapon 1 (drone) → Target 0 (truck) | Damage: 25.56 | Target HP left: 23.34
#   Weapon 2 (missile) is idle or cooling down.
#   Target 0 (truck): HP = 23.34, distance = 345669.33 m
#   Target 1 (tank): HP = 350.00, distance = 534129.67 m
#   Target 2 (commandcenter): HP = 481.66, distance = 453283.00 m
#
# --- Round 4 ---
#   Weapon 0 (artillery) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (missile) → Target 0 (truck) | Damage: 31.79 | Target HP left: 0.00
#   Target 0 (truck): Neutralized
#   Target 1 (tank): HP = 350.00, distance = 534118.56 m
#   Target 2 (commandcenter): HP = 481.66, distance = 453283.00 m
#
# --- Round 5 ---
#   Weapon 0 (artillery) → Target 2 (commandcenter) | Damage: 31.72 | Target HP left: 449.94
#   Weapon 1 (drone) → Target 2 (commandcenter) | Damage: 19.50 | Target HP left: 430.44
#   Weapon 2 (missile) is idle or cooling down.
#   Target 0 (truck): Neutralized
#   Target 1 (tank): HP = 350.00, distance = 534107.44 m
#   Target 2 (commandcenter): HP = 430.44, distance = 453283.00 m
#
# --- Round 6 ---
#   Weapon 0 (artillery) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (missile) is idle or cooling down.
#   Target 0 (truck): Neutralized
#   Target 1 (tank): HP = 350.00, distance = 534096.33 m
#   Target 2 (commandcenter): HP = 430.44, distance = 453283.00 m
#
# --- Round 7 ---
#   Weapon 0 (artillery) is idle or cooling down.
#   Weapon 1 (drone) → Target 2 (commandcenter) | Damage: 19.50 | Target HP left: 410.93
#   Weapon 2 (missile) → Target 2 (commandcenter) | Damage: 18.34 | Target HP left: 392.59
#   Target 0 (truck): Neutralized
#   Target 1 (tank): HP = 350.00, distance = 534085.22 m
#   Target 2 (commandcenter): HP = 392.59, distance = 453283.00 m
#
# --- Round 8 ---
#   Weapon 0 (artillery) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (missile) is idle or cooling down.
#   Target 0 (truck): Neutralized
#   Target 1 (tank): HP = 350.00, distance = 534074.11 m
#   Target 2 (commandcenter): HP = 392.59, distance = 453283.00 m
#
# --- Round 9 ---
#   Weapon 0 (artillery) → Target 2 (commandcenter) | Damage: 31.72 | Target HP left: 360.87
#   Weapon 1 (drone) → Target 2 (commandcenter) | Damage: 19.50 | Target HP left: 341.37
#   Weapon 2 (missile) is idle or cooling down.
#   Target 0 (truck): Neutralized
#   Target 1 (tank): HP = 350.00, distance = 534063.00 m
#   Target 2 (commandcenter): HP = 341.37, distance = 453283.00 m
#
# --- Round 10 ---
#   Weapon 0 (artillery) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (missile) → Target 2 (commandcenter) | Damage: 18.34 | Target HP left: 323.03
#   Target 0 (truck): Neutralized
#   Target 1 (tank): HP = 350.00, distance = 534051.89 m
#   Target 2 (commandcenter): HP = 323.03, distance = 453283.00 m
#
# --- Round 11 ---
#   Weapon 0 (artillery) is idle or cooling down.
#   Weapon 1 (drone) → Target 2 (commandcenter) | Damage: 19.50 | Target HP left: 303.53
#   Weapon 2 (missile) is idle or cooling down.
#   Target 0 (truck): Neutralized
#   Target 1 (tank): HP = 350.00, distance = 534040.78 m
#   Target 2 (commandcenter): HP = 303.53, distance = 453283.00 m
#
# --- Round 12 ---
#   Weapon 0 (artillery) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (missile) is idle or cooling down.
#   Target 0 (truck): Neutralized
#   Target 1 (tank): HP = 350.00, distance = 534029.67 m
#   Target 2 (commandcenter): HP = 303.53, distance = 453283.00 m
#
# --- Round 13 ---
#   Weapon 0 (artillery) → Target 2 (commandcenter) | Damage: 31.72 | Target HP left: 271.81
#   Weapon 1 (drone) → Target 2 (commandcenter) | Damage: 19.50 | Target HP left: 252.30
#   Weapon 2 (missile) → Target 1 (tank) | Damage: 8.25 | Target HP left: 341.75
#   Target 0 (truck): Neutralized
#   Target 1 (tank): HP = 341.75, distance = 534018.56 m
#   Target 2 (commandcenter): HP = 252.30, distance = 453283.00 m
#
# --- Round 14 ---
#   Weapon 0 (artillery) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (missile) is idle or cooling down.
#   Target 0 (truck): Neutralized
#   Target 1 (tank): HP = 341.75, distance = 534007.44 m
#   Target 2 (commandcenter): HP = 252.30, distance = 453283.00 m
#
# --- Round 15 ---
#   Weapon 0 (artillery) is idle or cooling down.
#   Weapon 1 (drone) → Target 2 (commandcenter) | Damage: 19.50 | Target HP left: 232.80
#   Weapon 2 (missile) is idle or cooling down.
#   Target 0 (truck): Neutralized
#   Target 1 (tank): HP = 341.75, distance = 533996.33 m
#   Target 2 (commandcenter): HP = 232.80, distance = 453283.00 m
#
# --- Round 16 ---
#   Weapon 0 (artillery) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (missile) → Target 2 (commandcenter) | Damage: 18.34 | Target HP left: 214.46
#   Target 0 (truck): Neutralized
#   Target 1 (tank): HP = 341.75, distance = 533985.22 m
#   Target 2 (commandcenter): HP = 214.46, distance = 453283.00 m
#
# --- Round 17 ---
#   Weapon 0 (artillery) → Target 2 (commandcenter) | Damage: 31.72 | Target HP left: 182.74
#   Weapon 1 (drone) → Target 2 (commandcenter) | Damage: 19.50 | Target HP left: 163.24
#   Weapon 2 (missile) is idle or cooling down.
#   Target 0 (truck): Neutralized
#   Target 1 (tank): HP = 341.75, distance = 533974.11 m
#   Target 2 (commandcenter): HP = 163.24, distance = 453283.00 m
#
# --- Round 18 ---
#   Weapon 0 (artillery) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (missile) is idle or cooling down.
#   Target 0 (truck): Neutralized
#   Target 1 (tank): HP = 341.75, distance = 533963.00 m
#   Target 2 (commandcenter): HP = 163.24, distance = 453283.00 m
#
# --- Round 19 ---
#   Weapon 0 (artillery) is idle or cooling down.
#   Weapon 1 (drone) → Target 2 (commandcenter) | Damage: 19.50 | Target HP left: 143.74
#   Weapon 2 (missile) → Target 2 (commandcenter) | Damage: 18.34 | Target HP left: 125.40
#   Target 0 (truck): Neutralized
#   Target 1 (tank): HP = 341.75, distance = 533951.89 m
#   Target 2 (commandcenter): HP = 125.40, distance = 453283.00 m
#
# --- Round 20 ---
#   Weapon 0 (artillery) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (missile) is idle or cooling down.
#   Target 0 (truck): Neutralized
#   Target 1 (tank): HP = 341.75, distance = 533940.78 m
#   Target 2 (commandcenter): HP = 125.40, distance = 453283.00 m
#
# --- Round 21 ---
#   Weapon 0 (artillery) → Target 2 (commandcenter) | Damage: 31.72 | Target HP left: 93.68
#   Weapon 1 (drone) → Target 2 (commandcenter) | Damage: 19.50 | Target HP left: 74.17
#   Weapon 2 (missile) is idle or cooling down.
#   Target 0 (truck): Neutralized
#   Target 1 (tank): HP = 341.75, distance = 533929.67 m
#   Target 2 (commandcenter): HP = 74.17, distance = 453283.00 m
#
# --- Round 22 ---
#   Weapon 0 (artillery) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (missile) → Target 2 (commandcenter) | Damage: 18.34 | Target HP left: 55.83
#   Target 0 (truck): Neutralized
#   Target 1 (tank): HP = 341.75, distance = 533918.56 m
#   Target 2 (commandcenter): HP = 55.83, distance = 453283.00 m
#
# --- Round 23 ---
#   Weapon 0 (artillery) is idle or cooling down.
#   Weapon 1 (drone) → Target 2 (commandcenter) | Damage: 19.50 | Target HP left: 36.33
#   Weapon 2 (missile) is idle or cooling down.
#   Target 0 (truck): Neutralized
#   Target 1 (tank): HP = 341.75, distance = 533907.44 m
#   Target 2 (commandcenter): HP = 36.33, distance = 453283.00 m
#
# --- Round 24 ---
#   Weapon 0 (artillery) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (missile) is idle or cooling down.
#   Target 0 (truck): Neutralized
#   Target 1 (tank): HP = 341.75, distance = 533896.33 m
#   Target 2 (commandcenter): HP = 36.33, distance = 453283.00 m
#
# --- Round 25 ---
#   Weapon 0 (artillery) → Target 2 (commandcenter) | Damage: 31.72 | Target HP left: 4.61
#   Weapon 1 (drone) → Target 2 (commandcenter) | Damage: 19.50 | Target HP left: 0.00
#   Weapon 2 (missile) → Target 1 (tank) | Damage: 8.26 | Target HP left: 333.49
#   Target 0 (truck): Neutralized
#   Target 1 (tank): HP = 333.49, distance = 533885.22 m
#   Target 2 (commandcenter): Neutralized
#
# --- Round 26 ---
#   Weapon 0 (artillery) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (missile) is idle or cooling down.
#   Target 0 (truck): Neutralized
#   Target 1 (tank): HP = 333.49, distance = 533874.11 m
#   Target 2 (commandcenter): Neutralized
#
# --- Round 27 ---
#   Weapon 0 (artillery) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (tank) | Damage: 14.97 | Target HP left: 318.52
#   Weapon 2 (missile) is idle or cooling down.
#   Target 0 (truck): Neutralized
#   Target 1 (tank): HP = 318.52, distance = 533863.00 m
#   Target 2 (commandcenter): Neutralized
#
# --- Round 28 ---
#   Weapon 0 (artillery) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (missile) → Target 1 (tank) | Damage: 8.27 | Target HP left: 310.25
#   Target 0 (truck): Neutralized
#   Target 1 (tank): HP = 310.25, distance = 533851.89 m
#   Target 2 (commandcenter): Neutralized
#
# --- Round 29 ---
#   Weapon 0 (artillery) → Target 1 (tank) | Damage: 21.36 | Target HP left: 288.89
#   Weapon 1 (drone) → Target 1 (tank) | Damage: 14.97 | Target HP left: 273.91
#   Weapon 2 (missile) is idle or cooling down.
#   Target 0 (truck): Neutralized
#   Target 1 (tank): HP = 273.91, distance = 533840.78 m
#   Target 2 (commandcenter): Neutralized
#
# --- Round 30 ---
#   Weapon 0 (artillery) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (missile) is idle or cooling down.
#   Target 0 (truck): Neutralized
#   Target 1 (tank): HP = 273.91, distance = 533829.67 m
#   Target 2 (commandcenter): Neutralized
#
# --- Round 31 ---
#   Weapon 0 (artillery) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (tank) | Damage: 14.97 | Target HP left: 258.94
#   Weapon 2 (missile) → Target 1 (tank) | Damage: 8.27 | Target HP left: 250.67
#   Target 0 (truck): Neutralized
#   Target 1 (tank): HP = 250.67, distance = 533818.56 m
#   Target 2 (commandcenter): Neutralized
#
# --- Round 32 ---
#   Weapon 0 (artillery) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (missile) is idle or cooling down.
#   Target 0 (truck): Neutralized
#   Target 1 (tank): HP = 250.67, distance = 533807.44 m
#   Target 2 (commandcenter): Neutralized
#
# --- Round 33 ---
#   Weapon 0 (artillery) → Target 1 (tank) | Damage: 21.37 | Target HP left: 229.30
#   Weapon 1 (drone) → Target 1 (tank) | Damage: 14.97 | Target HP left: 214.33
#   Weapon 2 (missile) is idle or cooling down.
#   Target 0 (truck): Neutralized
#   Target 1 (tank): HP = 214.33, distance = 533796.33 m
#   Target 2 (commandcenter): Neutralized
#
# --- Round 34 ---
#   Weapon 0 (artillery) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (missile) → Target 1 (tank) | Damage: 8.28 | Target HP left: 206.05
#   Target 0 (truck): Neutralized
#   Target 1 (tank): HP = 206.05, distance = 533785.22 m
#   Target 2 (commandcenter): Neutralized
#
# --- Round 35 ---
#   Weapon 0 (artillery) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (tank) | Damage: 14.98 | Target HP left: 191.07
#   Weapon 2 (missile) is idle or cooling down.
#   Target 0 (truck): Neutralized
#   Target 1 (tank): HP = 191.07, distance = 533774.11 m
#   Target 2 (commandcenter): Neutralized
#
# --- Round 36 ---
#   Weapon 0 (artillery) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (missile) is idle or cooling down.
#   Target 0 (truck): Neutralized
#   Target 1 (tank): HP = 191.07, distance = 533763.00 m
#   Target 2 (commandcenter): Neutralized
#
# --- Round 37 ---
#   Weapon 0 (artillery) → Target 1 (tank) | Damage: 21.37 | Target HP left: 169.70
#   Weapon 1 (drone) → Target 1 (tank) | Damage: 14.98 | Target HP left: 154.72
#   Weapon 2 (missile) is idle or cooling down.
#   Target 0 (truck): Neutralized
#   Target 1 (tank): HP = 154.72, distance = 533751.89 m
#   Target 2 (commandcenter): Neutralized
#
# --- Round 38 ---
#   Weapon 0 (artillery) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (missile) → Target 1 (tank) | Damage: 8.28 | Target HP left: 146.44
#   Target 0 (truck): Neutralized
#   Target 1 (tank): HP = 146.44, distance = 533740.78 m
#   Target 2 (commandcenter): Neutralized
#
# --- Round 39 ---
#   Weapon 0 (artillery) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (tank) | Damage: 14.98 | Target HP left: 131.46
#   Weapon 2 (missile) is idle or cooling down.
#   Target 0 (truck): Neutralized
#   Target 1 (tank): HP = 131.46, distance = 533729.67 m
#   Target 2 (commandcenter): Neutralized
#
# --- Round 40 ---
#   Weapon 0 (artillery) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (missile) is idle or cooling down.
#   Target 0 (truck): Neutralized
#   Target 1 (tank): HP = 131.46, distance = 533718.56 m
#   Target 2 (commandcenter): Neutralized
#
# --- Round 41 ---
#   Weapon 0 (artillery) → Target 1 (tank) | Damage: 21.38 | Target HP left: 110.08
#   Weapon 1 (drone) → Target 1 (tank) | Damage: 14.98 | Target HP left: 95.10
#   Weapon 2 (missile) is idle or cooling down.
#   Target 0 (truck): Neutralized
#   Target 1 (tank): HP = 95.10, distance = 533707.44 m
#   Target 2 (commandcenter): Neutralized
#
# --- Round 42 ---
#   Weapon 0 (artillery) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (missile) → Target 1 (tank) | Damage: 8.29 | Target HP left: 86.82
#   Target 0 (truck): Neutralized
#   Target 1 (tank): HP = 86.82, distance = 533696.33 m
#   Target 2 (commandcenter): Neutralized
#
# --- Round 43 ---
#   Weapon 0 (artillery) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (tank) | Damage: 14.98 | Target HP left: 71.84
#   Weapon 2 (missile) is idle or cooling down.
#   Target 0 (truck): Neutralized
#   Target 1 (tank): HP = 71.84, distance = 533685.22 m
#   Target 2 (commandcenter): Neutralized
#
# --- Round 44 ---
#   Weapon 0 (artillery) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (missile) is idle or cooling down.
#   Target 0 (truck): Neutralized
#   Target 1 (tank): HP = 71.84, distance = 533674.11 m
#   Target 2 (commandcenter): Neutralized
#
# --- Round 45 ---
#   Weapon 0 (artillery) → Target 1 (tank) | Damage: 21.39 | Target HP left: 50.45
#   Weapon 1 (drone) → Target 1 (tank) | Damage: 14.98 | Target HP left: 35.47
#   Weapon 2 (missile) is idle or cooling down.
#   Target 0 (truck): Neutralized
#   Target 1 (tank): HP = 35.47, distance = 533663.00 m
#   Target 2 (commandcenter): Neutralized
#
# --- Round 46 ---
#   Weapon 0 (artillery) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (missile) → Target 1 (tank) | Damage: 8.29 | Target HP left: 27.17
#   Target 0 (truck): Neutralized
#   Target 1 (tank): HP = 27.17, distance = 533651.89 m
#   Target 2 (commandcenter): Neutralized
#
# --- Round 47 ---
#   Weapon 0 (artillery) is idle or cooling down.
#   Weapon 1 (drone) → Target 1 (tank) | Damage: 14.98 | Target HP left: 12.19
#   Weapon 2 (missile) is idle or cooling down.
#   Target 0 (truck): Neutralized
#   Target 1 (tank): HP = 12.19, distance = 533640.78 m
#   Target 2 (commandcenter): Neutralized
#
# --- Round 48 ---
#   Weapon 0 (artillery) is idle or cooling down.
#   Weapon 1 (drone) is idle or cooling down.
#   Weapon 2 (missile) is idle or cooling down.
#   Target 0 (truck): Neutralized
#   Target 1 (tank): HP = 12.19, distance = 533629.67 m
#   Target 2 (commandcenter): Neutralized
#
# --- Round 49 ---
#   Weapon 0 (artillery) → Target 1 (tank) | Damage: 21.39 | Target HP left: 0.00
#   Weapon 1 (drone) → Target 1 (tank) | Damage: 14.98 | Target HP left: 0.00
#   Weapon 2 (missile) is idle or cooling down.
#   Target 0 (truck): Neutralized
#   Target 1 (tank): Neutralized
#   Target 2 (commandcenter): Neutralized
#
# ✅ All targets neutralized in 49 rounds.

# %%
import random

# ——————————————— Weapon and Target Stats ———————————————

weapon_stats = {
    "missile":           {"damage": 90, "cooldown": 2, "range": 700_000, "speed": (400*1e3)/3600},
    "drone":             {"damage": 50, "cooldown": 1, "range": 900_000, "speed": (260*1e3)/3600},
    "artillery":         {"damage": 110, "cooldown": 3, "range": 800_000, "speed": (100*1e3)/3600},
    "sam":               {"damage": 70, "cooldown": 2, "range": 600_000, "speed": (450*1e3)/3600},
    "tankgun":           {"damage": 60, "cooldown": 2, "range": 350_000, "speed": (120*1e3)/3600},
    "torpedo":           {"damage": 130, "cooldown": 4, "range": 500_000, "speed": (90*1e3)/3600},
    "empdevice":         {"damage": 40, "cooldown": 1, "range": 350_000, "speed": (500*1e3)/3600},
    "railgun":           {"damage": 150, "cooldown": 4, "range": 1_000_000, "speed": (800*1e3)/3600},
    "flakgun":           {"damage": 55, "cooldown": 1, "range": 400_000, "speed": (300*1e3)/3600},
    "antitankrocket":    {"damage": 80, "cooldown": 2, "range": 300_000, "speed": (250*1e3)/3600}
}

target_stats = {
    "tank":                   {"armor": 40, "speed": (50*1e3)/3600},
    "infantry":               {"armor": 10, "speed": (70*1e3)/3600},
    "radar":                  {"armor": 15, "speed": 0},
    "aircraft":               {"armor": 25, "speed": (200*1e3)/3600},
    "truck":                  {"armor": 15, "speed": (60*1e3)/3600},
    "commandcenter":          {"armor": 60, "speed": 0},
    "submarine":              {"armor": 45, "speed": (30*1e3)/3600},
    "destroyer":              {"armor": 50, "speed": (40*1e3)/3600},
    "supplyship":             {"armor": 35, "speed": (25*1e3)/3600},
    "snipernest":             {"armor": 20, "speed": 0},
    "supplydepot":            {"armor": 30, "speed": 0},
    "electronicwarfareunit":  {"armor": 30, "speed": 0}
}

# ——————————————— Scenario Configurations ———————————————

scenario_weapons = {
    "urban_battlefield":  ["artillery","drone","tankgun","flakgun","empdevice"],
    "airfield_defense":   ["missile","sam","drone","flakgun","railgun"],
    "convoy_ambush":      ["artillery","drone","missile","antitankrocket","tankgun"],
    "mountain_warfare":   ["artillery","drone","missile","tankgun","flakgun"],
    "naval_battle":       ["torpedo","missile","drone","sam","flakgun"],
    "desert_conflict":    ["missile","artillery","drone","sam","tankgun"],
    "jungle_ambush":      ["drone","missile","artillery","flakgun","antitankrocket"]
}

scenario_targets = {
    "urban_battlefield":  ["tank","infantry","radar","snipernest","supplydepot"],
    "airfield_defense":   ["aircraft","radar","commandcenter","infantry"],
    "convoy_ambush":      ["truck","tank","commandcenter","infantry"],
    "mountain_warfare":   ["snipernest","tank","infantry","radar","supplydepot"],
    "naval_battle":       ["destroyer","submarine","aircraft","radar","supplyship"],
    "desert_conflict":    ["tank","infantry","truck","commandcenter","radar"],
    "jungle_ambush":      ["infantry","snipernest","commandcenter","radar"]
}

# ——————————————— Simulation Engine ———————————————

def compute_threat_levels(targets, k=200000):
    return [(target_stats[t["type"]]["armor"]/max(t["distance"],1)) + (k/(t["distance"]**2)) for t in targets]

def compute_effectiveness(weapons, targets):
    matrix = [[0]*len(targets) for _ in weapons]
    for i,w in enumerate(weapons):
        ws = weapon_stats[w["type"]]
        for j,t in enumerate(targets):
            dist = t["distance"]
            if dist>ws["range"]: continue
            rm = max(0.1,1-dist/ws["range"])
            eff=(ws["damage"]*rm)/(target_stats[t["type"]]["armor"]+1)
            matrix[i][j] = min(1,eff/2)
    return matrix

def update_distances(targets):
    for t in targets:
        sp=target_stats[t["type"]]["speed"]
        t["distance"]=max(0, t["distance"]-sp)

def simulate_battle_hp(weapons, targets, max_rounds=500):
    hp=[target_stats[t["type"]]["armor"]*10 for t in targets]
    for w in weapons: w["ready_in"]=0

    for r in range(1,max_rounds+1):
        print(f"\n--- Round {r} ---")
        update_distances(targets)
        threats=compute_threat_levels(targets)
        effects=compute_effectiveness(weapons,targets)
        assigns=[-1]*len(weapons); load=[0]*len(targets)

        for i,w in enumerate(weapons):
            if w["ready_in"]>0:
                w["ready_in"]-=1; continue
            best,bs=-1,-1
            for j,t in enumerate(targets):
                if hp[j]<=0 or load[j]>=3 or t["distance"]>weapon_stats[w["type"]]["range"]: continue
                sc=effects[i][j]*threats[j]
                if sc>bs: best,bs=j,sc
            if best>=0:
                assigns[i]=best; load[best]+=1
                w["ready_in"]=weapon_stats[w["type"]]["cooldown"]

        for i,ti in enumerate(assigns):
            if ti<0:
                print(f"  Weapon {weapons[i]['id']} ({weapons[i]['type']}) idle/cooling")
                continue
            wts=weapon_stats[weapons[i]["type"]]; dist=targets[ti]["distance"]
            rm=max(0.1,1-dist/wts["range"])
            dmg=wts["damage"]*rm
            hp[ti]=max(0,hp[ti]-dmg)
            print(f"  Weapon {weapons[i]['id']} ({weapons[i]['type']}) → Target {ti} "
                  f"({targets[ti]['type']}) | Damage: {dmg:.2f} | HP left: {hp[ti]:.2f}")

        done=True
        for idx,t in enumerate(targets):
            st="Neutralized" if hp[idx]<=0 else f"HP={hp[idx]:.2f}, dist={t['distance']:.2f}"
            print(f"  Target {idx} ({t['type']}): {st}")
            if hp[idx]>0: done=False
        if done:
            print(f"\n✅ All targets neutralized in {r} rounds.")
            return
    print("\n⚠️ Max rounds reached. Some targets remain.")

# ——————————————— Scenario Loader & Runner ———————————————

print("Available Scenarios:")
for s in scenario_weapons: print(" -", s)

sc = input("Type scenario to run: ").strip().lower()
if sc not in scenario_weapons:
    print("❌ Invalid scenario. Restart and pick a valid one.")
else:
    # create random sized armies
    ws = [{"id": i, "type": wt, "ready_in":0} for i, wt in enumerate(scenario_weapons[sc] * random.randint(1,3))]
    ts = [{"id": i, "type": tt, "distance": random.randint(200_000,800_000)} 
          for i, tt in enumerate(scenario_targets[sc] * random.randint(2,5))]
    simulate_battle_hp(ws,ts)
# Out:
# Available Scenarios:
#  - urban_battlefield
#  - airfield_defense
#  - convoy_ambush
#  - mountain_warfare
#  - naval_battle
#  - desert_conflict
#  - jungle_ambush
# Type scenario to run:  convoy_ambush
# --- Round 1 ---
#   Weapon 0 (artillery) → Target 5 (tank) | Damage: 62.84 | HP left: 337.16
#   Weapon 1 (drone) → Target 8 (truck) | Damage: 35.44 | HP left: 114.56
#   Weapon 2 (missile) → Target 5 (tank) | Damage: 45.90 | HP left: 291.26
#   Weapon 3 (antitankrocket) → Target 7 (infantry) | Damage: 22.87 | HP left: 77.13
#   Weapon 4 (tankgun) → Target 7 (infantry) | Damage: 23.27 | HP left: 53.86
#   Weapon 5 (artillery) → Target 5 (tank) | Damage: 62.84 | HP left: 228.42
#   Weapon 6 (drone) → Target 8 (truck) | Damage: 35.44 | HP left: 79.13
#   Weapon 7 (missile) → Target 8 (truck) | Damage: 56.30 | HP left: 22.83
#   Weapon 8 (antitankrocket) → Target 7 (infantry) | Damage: 22.87 | HP left: 30.99
#   Weapon 9 (tankgun) idle/cooling
#   Weapon 10 (artillery) → Target 10 (commandcenter) | Damage: 54.56 | HP left: 545.44
#   Weapon 11 (drone) → Target 10 (commandcenter) | Damage: 27.60 | HP left: 517.84
#   Weapon 12 (missile) → Target 10 (commandcenter) | Damage: 38.16 | HP left: 479.68
#   Weapon 13 (antitankrocket) idle/cooling
#   Weapon 14 (tankgun) idle/cooling
#   Target 0 (truck): HP=150.00, dist=685069.33
#   Target 1 (tank): HP=400.00, dist=652479.11
#   Target 2 (commandcenter): HP=600.00, dist=530867.00
#   Target 3 (infantry): HP=100.00, dist=775570.56
#   Target 4 (truck): HP=150.00, dist=581719.33
#   Target 5 (tank): HP=228.42, dist=342982.11
#   Target 6 (commandcenter): HP=600.00, dist=519228.00
#   Target 7 (infantry): HP=30.99, dist=214243.56
#   Target 8 (truck): HP=22.83, dist=262134.33
#   Target 9 (tank): HP=400.00, dist=464921.11
#   Target 10 (commandcenter): HP=479.68, dist=403208.00
#   Target 11 (infantry): HP=100.00, dist=659711.56
#
# --- Round 2 ---
#   Weapon 0 (artillery) idle/cooling
#   Weapon 1 (drone) idle/cooling
#   Weapon 2 (missile) idle/cooling
#   Weapon 3 (antitankrocket) idle/cooling
#   Weapon 4 (tankgun) idle/cooling
#   Weapon 5 (artillery) idle/cooling
#   Weapon 6 (drone) idle/cooling
#   Weapon 7 (missile) idle/cooling
#   Weapon 8 (antitankrocket) idle/cooling
#   Weapon 9 (tankgun) → Target 7 (infantry) | Damage: 23.28 | HP left: 7.71
#   Weapon 10 (artillery) idle/cooling
#   Weapon 11 (drone) idle/cooling
#   Weapon 12 (missile) idle/cooling
#   Weapon 13 (antitankrocket) → Target 7 (infantry) | Damage: 22.87 | HP left: 0.00
#   Weapon 14 (tankgun) → Target 7 (infantry) | Damage: 23.28 | HP left: 0.00
#   Target 0 (truck): HP=150.00, dist=685052.67
#   Target 1 (tank): HP=400.00, dist=652465.22
#   Target 2 (commandcenter): HP=600.00, dist=530867.00
#   Target 3 (infantry): HP=100.00, dist=775551.11
#   Target 4 (truck): HP=150.00, dist=581702.67
#   Target 5 (tank): HP=228.42, dist=342968.22
#   Target 6 (commandcenter): HP=600.00, dist=519228.00
#   Target 7 (infantry): Neutralized
#   Target 8 (truck): HP=22.83, dist=262117.67
#   Target 9 (tank): HP=400.00, dist=464907.22
#   Target 10 (commandcenter): HP=479.68, dist=403208.00
#   Target 11 (infantry): HP=100.00, dist=659692.11
#
# --- Round 3 ---
#   Weapon 0 (artillery) idle/cooling
#   Weapon 1 (drone) → Target 8 (truck) | Damage: 35.44 | HP left: 0.00
#   Weapon 2 (missile) idle/cooling
#   Weapon 3 (antitankrocket) idle/cooling
#   Weapon 4 (tankgun) idle/cooling
#   Weapon 5 (artillery) idle/cooling
#   Weapon 6 (drone) → Target 8 (truck) | Damage: 35.44 | HP left: 0.00
#   Weapon 7 (missile) idle/cooling
#   Weapon 8 (antitankrocket) idle/cooling
#   Weapon 9 (tankgun) idle/cooling
#   Weapon 10 (artillery) idle/cooling
#   Weapon 11 (drone) → Target 8 (truck) | Damage: 35.44 | HP left: 0.00
#   Weapon 12 (missile) idle/cooling
#   Weapon 13 (antitankrocket) idle/cooling
#   Weapon 14 (tankgun) idle/cooling
#   Target 0 (truck): HP=150.00, dist=685036.00
#   Target 1 (tank): HP=400.00, dist=652451.33
#   Target 2 (commandcenter): HP=600.00, dist=530867.00
#   Target 3 (infantry): HP=100.00, dist=775531.67
#   Target 4 (truck): HP=150.00, dist=581686.00
#   Target 5 (tank): HP=228.42, dist=342954.33
#   Target 6 (commandcenter): HP=600.00, dist=519228.00
#   Target 7 (infantry): Neutralized
#   Target 8 (truck): Neutralized
#   Target 9 (tank): HP=400.00, dist=464893.33
#   Target 10 (commandcenter): HP=479.68, dist=403208.00
#   Target 11 (infantry): HP=100.00, dist=659672.67
#
# --- Round 4 ---
#   Weapon 0 (artillery) idle/cooling
#   Weapon 1 (drone) idle/cooling
#   Weapon 2 (missile) → Target 5 (tank) | Damage: 45.91 | HP left: 182.51
#   Weapon 3 (antitankrocket) idle/cooling
#   Weapon 4 (tankgun) → Target 5 (tank) | Damage: 6.00 | HP left: 176.51
#   Weapon 5 (artillery) idle/cooling
#   Weapon 6 (drone) idle/cooling
#   Weapon 7 (missile) → Target 5 (tank) | Damage: 45.91 | HP left: 130.60
#   Weapon 8 (antitankrocket) idle/cooling
#   Weapon 9 (tankgun) idle/cooling
#   Weapon 10 (artillery) idle/cooling
#   Weapon 11 (drone) idle/cooling
#   Weapon 12 (missile) → Target 10 (commandcenter) | Damage: 38.16 | HP left: 441.52
#   Weapon 13 (antitankrocket) idle/cooling
#   Weapon 14 (tankgun) idle/cooling
#   Target 0 (truck): HP=150.00, dist=685019.33
#   Target 1 (tank): HP=400.00, dist=652437.44
#   Target 2 (commandcenter): HP=600.00, dist=530867.00
#   Target 3 (infantry): HP=100.00, dist=775512.22
#   Target 4 (truck): HP=150.00, dist=581669.33
#   Target 5 (tank): HP=130.60, dist=342940.44
#   Target 6 (commandcenter): HP=600.00, dist=519228.00
#   Target 7 (infantry): Neutralized
#   Target 8 (truck): Neutralized
#   Target 9 (tank): HP=400.00, dist=464879.44
#   Target 10 (commandcenter): HP=441.52, dist=403208.00
#   Target 11 (infantry): HP=100.00, dist=659653.22
#
# --- Round 5 ---
#   Weapon 0 (artillery) → Target 5 (tank) | Damage: 62.85 | HP left: 67.75
#   Weapon 1 (drone) → Target 5 (tank) | Damage: 30.95 | HP left: 36.81
#   Weapon 2 (missile) idle/cooling
#   Weapon 3 (antitankrocket) idle/cooling
#   Weapon 4 (tankgun) idle/cooling
#   Weapon 5 (artillery) → Target 5 (tank) | Damage: 62.85 | HP left: 0.00
#   Weapon 6 (drone) → Target 10 (commandcenter) | Damage: 27.60 | HP left: 413.92
#   Weapon 7 (missile) idle/cooling
#   Weapon 8 (antitankrocket) idle/cooling
#   Weapon 9 (tankgun) idle/cooling
#   Weapon 10 (artillery) → Target 10 (commandcenter) | Damage: 54.56 | HP left: 359.37
#   Weapon 11 (drone) → Target 10 (commandcenter) | Damage: 27.60 | HP left: 331.77
#   Weapon 12 (missile) idle/cooling
#   Weapon 13 (antitankrocket) idle/cooling
#   Weapon 14 (tankgun) idle/cooling
#   Target 0 (truck): HP=150.00, dist=685002.67
#   Target 1 (tank): HP=400.00, dist=652423.56
#   Target 2 (commandcenter): HP=600.00, dist=530867.00
#   Target 3 (infantry): HP=100.00, dist=775492.78
#   Target 4 (truck): HP=150.00, dist=581652.67
#   Target 5 (tank): Neutralized
#   Target 6 (commandcenter): HP=600.00, dist=519228.00
#   Target 7 (infantry): Neutralized
#   Target 8 (truck): Neutralized
#   Target 9 (tank): HP=400.00, dist=464865.56
#   Target 10 (commandcenter): HP=331.77, dist=403208.00
#   Target 11 (infantry): HP=100.00, dist=659633.78
#
# --- Round 6 ---
#   Weapon 0 (artillery) idle/cooling
#   Weapon 1 (drone) idle/cooling
#   Weapon 2 (missile) idle/cooling
#   Weapon 3 (antitankrocket) idle/cooling
#   Weapon 4 (tankgun) idle/cooling
#   Weapon 5 (artillery) idle/cooling
#   Weapon 6 (drone) idle/cooling
#   Weapon 7 (missile) idle/cooling
#   Weapon 8 (antitankrocket) idle/cooling
#   Weapon 9 (tankgun) idle/cooling
#   Weapon 10 (artillery) idle/cooling
#   Weapon 11 (drone) idle/cooling
#   Weapon 12 (missile) idle/cooling
#   Weapon 13 (antitankrocket) idle/cooling
#   Weapon 14 (tankgun) idle/cooling
#   Target 0 (truck): HP=150.00, dist=684986.00
#   Target 1 (tank): HP=400.00, dist=652409.67
#   Target 2 (commandcenter): HP=600.00, dist=530867.00
#   Target 3 (infantry): HP=100.00, dist=775473.33
#   Target 4 (truck): HP=150.00, dist=581636.00
#   Target 5 (tank): Neutralized
#   Target 6 (commandcenter): HP=600.00, dist=519228.00
#   Target 7 (infantry): Neutralized
#   Target 8 (truck): Neutralized
#   Target 9 (tank): HP=400.00, dist=464851.67
#   Target 10 (commandcenter): HP=331.77, dist=403208.00
#   Target 11 (infantry): HP=100.00, dist=659614.33
#
# --- Round 7 ---
#   Weapon 0 (artillery) idle/cooling
#   Weapon 1 (drone) → Target 10 (commandcenter) | Damage: 27.60 | HP left: 304.17
#   Weapon 2 (missile) → Target 10 (commandcenter) | Damage: 38.16 | HP left: 266.01
#   Weapon 3 (antitankrocket) idle/cooling
#   Weapon 4 (tankgun) idle/cooling
#   Weapon 5 (artillery) idle/cooling
#   Weapon 6 (drone) → Target 10 (commandcenter) | Damage: 27.60 | HP left: 238.41
#   Weapon 7 (missile) → Target 9 (tank) | Damage: 30.24 | HP left: 369.76
#   Weapon 8 (antitankrocket) idle/cooling
#   Weapon 9 (tankgun) idle/cooling
#   Weapon 10 (artillery) idle/cooling
#   Weapon 11 (drone) → Target 9 (tank) | Damage: 24.18 | HP left: 345.59
#   Weapon 12 (missile) → Target 9 (tank) | Damage: 30.24 | HP left: 315.35
#   Weapon 13 (antitankrocket) idle/cooling
#   Weapon 14 (tankgun) idle/cooling
#   Target 0 (truck): HP=150.00, dist=684969.33
#   Target 1 (tank): HP=400.00, dist=652395.78
#   Target 2 (commandcenter): HP=600.00, dist=530867.00
#   Target 3 (infantry): HP=100.00, dist=775453.89
#   Target 4 (truck): HP=150.00, dist=581619.33
#   Target 5 (tank): Neutralized
#   Target 6 (commandcenter): HP=600.00, dist=519228.00
#   Target 7 (infantry): Neutralized
#   Target 8 (truck): Neutralized
#   Target 9 (tank): HP=315.35, dist=464837.78
#   Target 10 (commandcenter): HP=238.41, dist=403208.00
#   Target 11 (infantry): HP=100.00, dist=659594.89
#
# --- Round 8 ---
#   Weapon 0 (artillery) idle/cooling
#   Weapon 1 (drone) idle/cooling
#   Weapon 2 (missile) idle/cooling
#   Weapon 3 (antitankrocket) idle/cooling
#   Weapon 4 (tankgun) idle/cooling
#   Weapon 5 (artillery) idle/cooling
#   Weapon 6 (drone) idle/cooling
#   Weapon 7 (missile) idle/cooling
#   Weapon 8 (antitankrocket) idle/cooling
#   Weapon 9 (tankgun) idle/cooling
#   Weapon 10 (artillery) idle/cooling
#   Weapon 11 (drone) idle/cooling
#   Weapon 12 (missile) idle/cooling
#   Weapon 13 (antitankrocket) idle/cooling
#   Weapon 14 (tankgun) idle/cooling
#   Target 0 (truck): HP=150.00, dist=684952.67
#   Target 1 (tank): HP=400.00, dist=652381.89
#   Target 2 (commandcenter): HP=600.00, dist=530867.00
#   Target 3 (infantry): HP=100.00, dist=775434.44
#   Target 4 (truck): HP=150.00, dist=581602.67
#   Target 5 (tank): Neutralized
#   Target 6 (commandcenter): HP=600.00, dist=519228.00
#   Target 7 (infantry): Neutralized
#   Target 8 (truck): Neutralized
#   Target 9 (tank): HP=315.35, dist=464823.89
#   Target 10 (commandcenter): HP=238.41, dist=403208.00
#   Target 11 (infantry): HP=100.00, dist=659575.44
#
# --- Round 9 ---
#   Weapon 0 (artillery) → Target 10 (commandcenter) | Damage: 54.56 | HP left: 183.85
#   Weapon 1 (drone) → Target 10 (commandcenter) | Damage: 27.60 | HP left: 156.25
#   Weapon 2 (missile) idle/cooling
#   Weapon 3 (antitankrocket) idle/cooling
#   Weapon 4 (tankgun) idle/cooling
#   Weapon 5 (artillery) → Target 10 (commandcenter) | Damage: 54.56 | HP left: 101.69
#   Weapon 6 (drone) → Target 9 (tank) | Damage: 24.18 | HP left: 291.18
#   Weapon 7 (missile) idle/cooling
#   Weapon 8 (antitankrocket) idle/cooling
#   Weapon 9 (tankgun) idle/cooling
#   Weapon 10 (artillery) → Target 9 (tank) | Damage: 46.09 | HP left: 245.09
#   Weapon 11 (drone) → Target 9 (tank) | Damage: 24.18 | HP left: 220.91
#   Weapon 12 (missile) idle/cooling
#   Weapon 13 (antitankrocket) idle/cooling
#   Weapon 14 (tankgun) idle/cooling
#   Target 0 (truck): HP=150.00, dist=684936.00
#   Target 1 (tank): HP=400.00, dist=652368.00
#   Target 2 (commandcenter): HP=600.00, dist=530867.00
#   Target 3 (infantry): HP=100.00, dist=775415.00
#   Target 4 (truck): HP=150.00, dist=581586.00
#   Target 5 (tank): Neutralized
#   Target 6 (commandcenter): HP=600.00, dist=519228.00
#   Target 7 (infantry): Neutralized
#   Target 8 (truck): Neutralized
#   Target 9 (tank): HP=220.91, dist=464810.00
#   Target 10 (commandcenter): HP=101.69, dist=403208.00
#   Target 11 (infantry): HP=100.00, dist=659556.00
#
# --- Round 10 ---
#   Weapon 0 (artillery) idle/cooling
#   Weapon 1 (drone) idle/cooling
#   Weapon 2 (missile) → Target 10 (commandcenter) | Damage: 38.16 | HP left: 63.53
#   Weapon 3 (antitankrocket) idle/cooling
#   Weapon 4 (tankgun) idle/cooling
#   Weapon 5 (artillery) idle/cooling
#   Weapon 6 (drone) idle/cooling
#   Weapon 7 (missile) → Target 10 (commandcenter) | Damage: 38.16 | HP left: 25.37
#   Weapon 8 (antitankrocket) idle/cooling
#   Weapon 9 (tankgun) idle/cooling
#   Weapon 10 (artillery) idle/cooling
#   Weapon 11 (drone) idle/cooling
#   Weapon 12 (missile) → Target 10 (commandcenter) | Damage: 38.16 | HP left: 0.00
#   Weapon 13 (antitankrocket) idle/cooling
#   Weapon 14 (tankgun) idle/cooling
#   Target 0 (truck): HP=150.00, dist=684919.33
#   Target 1 (tank): HP=400.00, dist=652354.11
#   Target 2 (commandcenter): HP=600.00, dist=530867.00
#   Target 3 (infantry): HP=100.00, dist=775395.56
#   Target 4 (truck): HP=150.00, dist=581569.33
#   Target 5 (tank): Neutralized
#   Target 6 (commandcenter): HP=600.00, dist=519228.00
#   Target 7 (infantry): Neutralized
#   Target 8 (truck): Neutralized
#   Target 9 (tank): HP=220.91, dist=464796.11
#   Target 10 (commandcenter): Neutralized
#   Target 11 (infantry): HP=100.00, dist=659536.56
#
# --- Round 11 ---
#   Weapon 0 (artillery) idle/cooling
#   Weapon 1 (drone) → Target 9 (tank) | Damage: 24.18 | HP left: 196.73
#   Weapon 2 (missile) idle/cooling
#   Weapon 3 (antitankrocket) idle/cooling
#   Weapon 4 (tankgun) idle/cooling
#   Weapon 5 (artillery) idle/cooling
#   Weapon 6 (drone) → Target 9 (tank) | Damage: 24.18 | HP left: 172.55
#   Weapon 7 (missile) idle/cooling
#   Weapon 8 (antitankrocket) idle/cooling
#   Weapon 9 (tankgun) idle/cooling
#   Weapon 10 (artillery) idle/cooling
#   Weapon 11 (drone) → Target 9 (tank) | Damage: 24.18 | HP left: 148.37
#   Weapon 12 (missile) idle/cooling
#   Weapon 13 (antitankrocket) idle/cooling
#   Weapon 14 (tankgun) idle/cooling
#   Target 0 (truck): HP=150.00, dist=684902.67
#   Target 1 (tank): HP=400.00, dist=652340.22
#   Target 2 (commandcenter): HP=600.00, dist=530867.00
#   Target 3 (infantry): HP=100.00, dist=775376.11
#   Target 4 (truck): HP=150.00, dist=581552.67
#   Target 5 (tank): Neutralized
#   Target 6 (commandcenter): HP=600.00, dist=519228.00
#   Target 7 (infantry): Neutralized
#   Target 8 (truck): Neutralized
#   Target 9 (tank): HP=148.37, dist=464782.22
#   Target 10 (commandcenter): Neutralized
#   Target 11 (infantry): HP=100.00, dist=659517.11
#
# --- Round 12 ---
#   Weapon 0 (artillery) idle/cooling
#   Weapon 1 (drone) idle/cooling
#   Weapon 2 (missile) idle/cooling
#   Weapon 3 (antitankrocket) idle/cooling
#   Weapon 4 (tankgun) idle/cooling
#   Weapon 5 (artillery) idle/cooling
#   Weapon 6 (drone) idle/cooling
#   Weapon 7 (missile) idle/cooling
#   Weapon 8 (antitankrocket) idle/cooling
#   Weapon 9 (tankgun) idle/cooling
#   Weapon 10 (artillery) idle/cooling
#   Weapon 11 (drone) idle/cooling
#   Weapon 12 (missile) idle/cooling
#   Weapon 13 (antitankrocket) idle/cooling
#   Weapon 14 (tankgun) idle/cooling
#   Target 0 (truck): HP=150.00, dist=684886.00
#   Target 1 (tank): HP=400.00, dist=652326.33
#   Target 2 (commandcenter): HP=600.00, dist=530867.00
#   Target 3 (infantry): HP=100.00, dist=775356.67
#   Target 4 (truck): HP=150.00, dist=581536.00
#   Target 5 (tank): Neutralized
#   Target 6 (commandcenter): HP=600.00, dist=519228.00
#   Target 7 (infantry): Neutralized
#   Target 8 (truck): Neutralized
#   Target 9 (tank): HP=148.37, dist=464768.33
#   Target 10 (commandcenter): Neutralized
#   Target 11 (infantry): HP=100.00, dist=659497.67
#
# --- Round 13 ---
#   Weapon 0 (artillery) → Target 9 (tank) | Damage: 46.10 | HP left: 102.28
#   Weapon 1 (drone) → Target 9 (tank) | Damage: 24.18 | HP left: 78.10
#   Weapon 2 (missile) → Target 9 (tank) | Damage: 30.25 | HP left: 47.85
#   Weapon 3 (antitankrocket) idle/cooling
#   Weapon 4 (tankgun) idle/cooling
#   Weapon 5 (artillery) → Target 6 (commandcenter) | Damage: 38.61 | HP left: 561.39
#   Weapon 6 (drone) → Target 6 (commandcenter) | Damage: 21.15 | HP left: 540.24
#   Weapon 7 (missile) → Target 6 (commandcenter) | Damage: 23.24 | HP left: 517.00
#   Weapon 8 (antitankrocket) idle/cooling
#   Weapon 9 (tankgun) idle/cooling
#   Weapon 10 (artillery) → Target 2 (commandcenter) | Damage: 37.01 | HP left: 562.99
#   Weapon 11 (drone) → Target 2 (commandcenter) | Damage: 20.51 | HP left: 542.49
#   Weapon 12 (missile) → Target 2 (commandcenter) | Damage: 21.75 | HP left: 520.74
#   Weapon 13 (antitankrocket) idle/cooling
#   Weapon 14 (tankgun) idle/cooling
#   Target 0 (truck): HP=150.00, dist=684869.33
#   Target 1 (tank): HP=400.00, dist=652312.44
#   Target 2 (commandcenter): HP=520.74, dist=530867.00
#   Target 3 (infantry): HP=100.00, dist=775337.22
#   Target 4 (truck): HP=150.00, dist=581519.33
#   Target 5 (tank): Neutralized
#   Target 6 (commandcenter): HP=517.00, dist=519228.00
#   Target 7 (infantry): Neutralized
#   Target 8 (truck): Neutralized
#   Target 9 (tank): HP=47.85, dist=464754.44
#   Target 10 (commandcenter): Neutralized
#   Target 11 (infantry): HP=100.00, dist=659478.22
#
# --- Round 14 ---
#   Weapon 0 (artillery) idle/cooling
#   Weapon 1 (drone) idle/cooling
#   Weapon 2 (missile) idle/cooling
#   Weapon 3 (antitankrocket) idle/cooling
#   Weapon 4 (tankgun) idle/cooling
#   Weapon 5 (artillery) idle/cooling
#   Weapon 6 (drone) idle/cooling
#   Weapon 7 (missile) idle/cooling
#   Weapon 8 (antitankrocket) idle/cooling
#   Weapon 9 (tankgun) idle/cooling
#   Weapon 10 (artillery) idle/cooling
#   Weapon 11 (drone) idle/cooling
#   Weapon 12 (missile) idle/cooling
#   Weapon 13 (antitankrocket) idle/cooling
#   Weapon 14 (tankgun) idle/cooling
#   Target 0 (truck): HP=150.00, dist=684852.67
#   Target 1 (tank): HP=400.00, dist=652298.56
#   Target 2 (commandcenter): HP=520.74, dist=530867.00
#   Target 3 (infantry): HP=100.00, dist=775317.78
#   Target 4 (truck): HP=150.00, dist=581502.67
#   Target 5 (tank): Neutralized
#   Target 6 (commandcenter): HP=517.00, dist=519228.00
#   Target 7 (infantry): Neutralized
#   Target 8 (truck): Neutralized
#   Target 9 (tank): HP=47.85, dist=464740.56
#   Target 10 (commandcenter): Neutralized
#   Target 11 (infantry): HP=100.00, dist=659458.78
#
# --- Round 15 ---
#   Weapon 0 (artillery) idle/cooling
#   Weapon 1 (drone) → Target 9 (tank) | Damage: 24.18 | HP left: 23.67
#   Weapon 2 (missile) idle/cooling
#   Weapon 3 (antitankrocket) idle/cooling
#   Weapon 4 (tankgun) idle/cooling
#   Weapon 5 (artillery) idle/cooling
#   Weapon 6 (drone) → Target 9 (tank) | Damage: 24.18 | HP left: 0.00
#   Weapon 7 (missile) idle/cooling
#   Weapon 8 (antitankrocket) idle/cooling
#   Weapon 9 (tankgun) idle/cooling
#   Weapon 10 (artillery) idle/cooling
#   Weapon 11 (drone) → Target 9 (tank) | Damage: 24.18 | HP left: 0.00
#   Weapon 12 (missile) idle/cooling
#   Weapon 13 (antitankrocket) idle/cooling
#   Weapon 14 (tankgun) idle/cooling
#   Target 0 (truck): HP=150.00, dist=684836.00
#   Target 1 (tank): HP=400.00, dist=652284.67
#   Target 2 (commandcenter): HP=520.74, dist=530867.00
#   Target 3 (infantry): HP=100.00, dist=775298.33
#   Target 4 (truck): HP=150.00, dist=581486.00
#   Target 5 (tank): Neutralized
#   Target 6 (commandcenter): HP=517.00, dist=519228.00
#   Target 7 (infantry): Neutralized
#   Target 8 (truck): Neutralized
#   Target 9 (tank): Neutralized
#   Target 10 (commandcenter): Neutralized
#   Target 11 (infantry): HP=100.00, dist=659439.33
#
# --- Round 16 ---
#   Weapon 0 (artillery) idle/cooling
#   Weapon 1 (drone) idle/cooling
#   Weapon 2 (missile) → Target 6 (commandcenter) | Damage: 23.24 | HP left: 493.76
#   Weapon 3 (antitankrocket) idle/cooling
#   Weapon 4 (tankgun) idle/cooling
#   Weapon 5 (artillery) idle/cooling
#   Weapon 6 (drone) idle/cooling
#   Weapon 7 (missile) → Target 6 (commandcenter) | Damage: 23.24 | HP left: 470.51
#   Weapon 8 (antitankrocket) idle/cooling
#   Weapon 9 (tankgun) idle/cooling
#   Weapon 10 (artillery) idle/cooling
#   Weapon 11 (drone) idle/cooling
#   Weapon 12 (missile) → Target 6 (commandcenter) | Damage: 23.24 | HP left: 447.27
#   Weapon 13 (antitankrocket) idle/cooling
#   Weapon 14 (tankgun) idle/cooling
#   Target 0 (truck): HP=150.00, dist=684819.33
#   Target 1 (tank): HP=400.00, dist=652270.78
#   Target 2 (commandcenter): HP=520.74, dist=530867.00
#   Target 3 (infantry): HP=100.00, dist=775278.89
#   Target 4 (truck): HP=150.00, dist=581469.33
#   Target 5 (tank): Neutralized
#   Target 6 (commandcenter): HP=447.27, dist=519228.00
#   Target 7 (infantry): Neutralized
#   Target 8 (truck): Neutralized
#   Target 9 (tank): Neutralized
#   Target 10 (commandcenter): Neutralized
#   Target 11 (infantry): HP=100.00, dist=659419.89
#
# --- Round 17 ---
#   Weapon 0 (artillery) → Target 6 (commandcenter) | Damage: 38.61 | HP left: 408.67
#   Weapon 1 (drone) → Target 6 (commandcenter) | Damage: 21.15 | HP left: 387.51
#   Weapon 2 (missile) idle/cooling
#   Weapon 3 (antitankrocket) idle/cooling
#   Weapon 4 (tankgun) idle/cooling
#   Weapon 5 (artillery) → Target 6 (commandcenter) | Damage: 38.61 | HP left: 348.91
#   Weapon 6 (drone) → Target 2 (commandcenter) | Damage: 20.51 | HP left: 500.23
#   Weapon 7 (missile) idle/cooling
#   Weapon 8 (antitankrocket) idle/cooling
#   Weapon 9 (tankgun) idle/cooling
#   Weapon 10 (artillery) → Target 2 (commandcenter) | Damage: 37.01 | HP left: 463.23
#   Weapon 11 (drone) → Target 2 (commandcenter) | Damage: 20.51 | HP left: 442.72
#   Weapon 12 (missile) idle/cooling
#   Weapon 13 (antitankrocket) idle/cooling
#   Weapon 14 (tankgun) idle/cooling
#   Target 0 (truck): HP=150.00, dist=684802.67
#   Target 1 (tank): HP=400.00, dist=652256.89
#   Target 2 (commandcenter): HP=442.72, dist=530867.00
#   Target 3 (infantry): HP=100.00, dist=775259.44
#   Target 4 (truck): HP=150.00, dist=581452.67
#   Target 5 (tank): Neutralized
#   Target 6 (commandcenter): HP=348.91, dist=519228.00
#   Target 7 (infantry): Neutralized
#   Target 8 (truck): Neutralized
#   Target 9 (tank): Neutralized
#   Target 10 (commandcenter): Neutralized
#   Target 11 (infantry): HP=100.00, dist=659400.44
#
# --- Round 18 ---
#   Weapon 0 (artillery) idle/cooling
#   Weapon 1 (drone) idle/cooling
#   Weapon 2 (missile) idle/cooling
#   Weapon 3 (antitankrocket) idle/cooling
#   Weapon 4 (tankgun) idle/cooling
#   Weapon 5 (artillery) idle/cooling
#   Weapon 6 (drone) idle/cooling
#   Weapon 7 (missile) idle/cooling
#   Weapon 8 (antitankrocket) idle/cooling
#   Weapon 9 (tankgun) idle/cooling
#   Weapon 10 (artillery) idle/cooling
#   Weapon 11 (drone) idle/cooling
#   Weapon 12 (missile) idle/cooling
#   Weapon 13 (antitankrocket) idle/cooling
#   Weapon 14 (tankgun) idle/cooling
#   Target 0 (truck): HP=150.00, dist=684786.00
#   Target 1 (tank): HP=400.00, dist=652243.00
#   Target 2 (commandcenter): HP=442.72, dist=530867.00
#   Target 3 (infantry): HP=100.00, dist=775240.00
#   Target 4 (truck): HP=150.00, dist=581436.00
#   Target 5 (tank): Neutralized
#   Target 6 (commandcenter): HP=348.91, dist=519228.00
#   Target 7 (infantry): Neutralized
#   Target 8 (truck): Neutralized
#   Target 9 (tank): Neutralized
#   Target 10 (commandcenter): Neutralized
#   Target 11 (infantry): HP=100.00, dist=659381.00
#
# --- Round 19 ---
#   Weapon 0 (artillery) idle/cooling
#   Weapon 1 (drone) → Target 6 (commandcenter) | Damage: 21.15 | HP left: 327.75
#   Weapon 2 (missile) → Target 6 (commandcenter) | Damage: 23.24 | HP left: 304.51
#   Weapon 3 (antitankrocket) idle/cooling
#   Weapon 4 (tankgun) idle/cooling
#   Weapon 5 (artillery) idle/cooling
#   Weapon 6 (drone) → Target 6 (commandcenter) | Damage: 21.15 | HP left: 283.35
#   Weapon 7 (missile) → Target 2 (commandcenter) | Damage: 21.75 | HP left: 420.97
#   Weapon 8 (antitankrocket) idle/cooling
#   Weapon 9 (tankgun) idle/cooling
#   Weapon 10 (artillery) idle/cooling
#   Weapon 11 (drone) → Target 2 (commandcenter) | Damage: 20.51 | HP left: 400.47
#   Weapon 12 (missile) → Target 2 (commandcenter) | Damage: 21.75 | HP left: 378.72
#   Weapon 13 (antitankrocket) idle/cooling
#   Weapon 14 (tankgun) idle/cooling
#   Target 0 (truck): HP=150.00, dist=684769.33
#   Target 1 (tank): HP=400.00, dist=652229.11
#   Target 2 (commandcenter): HP=378.72, dist=530867.00
#   Target 3 (infantry): HP=100.00, dist=775220.56
#   Target 4 (truck): HP=150.00, dist=581419.33
#   Target 5 (tank): Neutralized
#   Target 6 (commandcenter): HP=283.35, dist=519228.00
#   Target 7 (infantry): Neutralized
#   Target 8 (truck): Neutralized
#   Target 9 (tank): Neutralized
#   Target 10 (commandcenter): Neutralized
#   Target 11 (infantry): HP=100.00, dist=659361.56
#
# --- Round 20 ---
#   Weapon 0 (artillery) idle/cooling
#   Weapon 1 (drone) idle/cooling
#   Weapon 2 (missile) idle/cooling
#   Weapon 3 (antitankrocket) idle/cooling
#   Weapon 4 (tankgun) idle/cooling
#   Weapon 5 (artillery) idle/cooling
#   Weapon 6 (drone) idle/cooling
#   Weapon 7 (missile) idle/cooling
#   Weapon 8 (antitankrocket) idle/cooling
#   Weapon 9 (tankgun) idle/cooling
#   Weapon 10 (artillery) idle/cooling
#   Weapon 11 (drone) idle/cooling
#   Weapon 12 (missile) idle/cooling
#   Weapon 13 (antitankrocket) idle/cooling
#   Weapon 14 (tankgun) idle/cooling
#   Target 0 (truck): HP=150.00, dist=684752.67
#   Target 1 (tank): HP=400.00, dist=652215.22
#   Target 2 (commandcenter): HP=378.72, dist=530867.00
#   Target 3 (infantry): HP=100.00, dist=775201.11
#   Target 4 (truck): HP=150.00, dist=581402.67
#   Target 5 (tank): Neutralized
#   Target 6 (commandcenter): HP=283.35, dist=519228.00
#   Target 7 (infantry): Neutralized
#   Target 8 (truck): Neutralized
#   Target 9 (tank): Neutralized
#   Target 10 (commandcenter): Neutralized
#   Target 11 (infantry): HP=100.00, dist=659342.11
#
# --- Round 21 ---
#   Weapon 0 (artillery) → Target 6 (commandcenter) | Damage: 38.61 | HP left: 244.75
#   Weapon 1 (drone) → Target 6 (commandcenter) | Damage: 21.15 | HP left: 223.59
#   Weapon 2 (missile) idle/cooling
#   Weapon 3 (antitankrocket) idle/cooling
#   Weapon 4 (tankgun) idle/cooling
#   Weapon 5 (artillery) → Target 6 (commandcenter) | Damage: 38.61 | HP left: 184.99
#   Weapon 6 (drone) → Target 2 (commandcenter) | Damage: 20.51 | HP left: 358.21
#   Weapon 7 (missile) idle/cooling
#   Weapon 8 (antitankrocket) idle/cooling
#   Weapon 9 (tankgun) idle/cooling
#   Weapon 10 (artillery) → Target 2 (commandcenter) | Damage: 37.01 | HP left: 321.21
#   Weapon 11 (drone) → Target 2 (commandcenter) | Damage: 20.51 | HP left: 300.70
#   Weapon 12 (missile) idle/cooling
#   Weapon 13 (antitankrocket) idle/cooling
#   Weapon 14 (tankgun) idle/cooling
#   Target 0 (truck): HP=150.00, dist=684736.00
#   Target 1 (tank): HP=400.00, dist=652201.33
#   Target 2 (commandcenter): HP=300.70, dist=530867.00
#   Target 3 (infantry): HP=100.00, dist=775181.67
#   Target 4 (truck): HP=150.00, dist=581386.00
#   Target 5 (tank): Neutralized
#   Target 6 (commandcenter): HP=184.99, dist=519228.00
#   Target 7 (infantry): Neutralized
#   Target 8 (truck): Neutralized
#   Target 9 (tank): Neutralized
#   Target 10 (commandcenter): Neutralized
#   Target 11 (infantry): HP=100.00, dist=659322.67
#
# --- Round 22 ---
#   Weapon 0 (artillery) idle/cooling
#   Weapon 1 (drone) idle/cooling
#   Weapon 2 (missile) → Target 6 (commandcenter) | Damage: 23.24 | HP left: 161.75
#   Weapon 3 (antitankrocket) idle/cooling
#   Weapon 4 (tankgun) idle/cooling
#   Weapon 5 (artillery) idle/cooling
#   Weapon 6 (drone) idle/cooling
#   Weapon 7 (missile) → Target 6 (commandcenter) | Damage: 23.24 | HP left: 138.50
#   Weapon 8 (antitankrocket) idle/cooling
#   Weapon 9 (tankgun) idle/cooling
#   Weapon 10 (artillery) idle/cooling
#   Weapon 11 (drone) idle/cooling
#   Weapon 12 (missile) → Target 6 (commandcenter) | Damage: 23.24 | HP left: 115.26
#   Weapon 13 (antitankrocket) idle/cooling
#   Weapon 14 (tankgun) idle/cooling
#   Target 0 (truck): HP=150.00, dist=684719.33
#   Target 1 (tank): HP=400.00, dist=652187.44
#   Target 2 (commandcenter): HP=300.70, dist=530867.00
#   Target 3 (infantry): HP=100.00, dist=775162.22
#   Target 4 (truck): HP=150.00, dist=581369.33
#   Target 5 (tank): Neutralized
#   Target 6 (commandcenter): HP=115.26, dist=519228.00
#   Target 7 (infantry): Neutralized
#   Target 8 (truck): Neutralized
#   Target 9 (tank): Neutralized
#   Target 10 (commandcenter): Neutralized
#   Target 11 (infantry): HP=100.00, dist=659303.22
#
# --- Round 23 ---
#   Weapon 0 (artillery) idle/cooling
#   Weapon 1 (drone) → Target 6 (commandcenter) | Damage: 21.15 | HP left: 94.11
#   Weapon 2 (missile) idle/cooling
#   Weapon 3 (antitankrocket) idle/cooling
#   Weapon 4 (tankgun) idle/cooling
#   Weapon 5 (artillery) idle/cooling
#   Weapon 6 (drone) → Target 6 (commandcenter) | Damage: 21.15 | HP left: 72.95
#   Weapon 7 (missile) idle/cooling
#   Weapon 8 (antitankrocket) idle/cooling
#   Weapon 9 (tankgun) idle/cooling
#   Weapon 10 (artillery) idle/cooling
#   Weapon 11 (drone) → Target 6 (commandcenter) | Damage: 21.15 | HP left: 51.80
#   Weapon 12 (missile) idle/cooling
#   Weapon 13 (antitankrocket) idle/cooling
#   Weapon 14 (tankgun) idle/cooling
#   Target 0 (truck): HP=150.00, dist=684702.67
#   Target 1 (tank): HP=400.00, dist=652173.56
#   Target 2 (commandcenter): HP=300.70, dist=530867.00
#   Target 3 (infantry): HP=100.00, dist=775142.78
#   Target 4 (truck): HP=150.00, dist=581352.67
#   Target 5 (tank): Neutralized
#   Target 6 (commandcenter): HP=51.80, dist=519228.00
#   Target 7 (infantry): Neutralized
#   Target 8 (truck): Neutralized
#   Target 9 (tank): Neutralized
#   Target 10 (commandcenter): Neutralized
#   Target 11 (infantry): HP=100.00, dist=659283.78
#
# --- Round 24 ---
#   Weapon 0 (artillery) idle/cooling
#   Weapon 1 (drone) idle/cooling
#   Weapon 2 (missile) idle/cooling
#   Weapon 3 (antitankrocket) idle/cooling
#   Weapon 4 (tankgun) idle/cooling
#   Weapon 5 (artillery) idle/cooling
#   Weapon 6 (drone) idle/cooling
#   Weapon 7 (missile) idle/cooling
#   Weapon 8 (antitankrocket) idle/cooling
#   Weapon 9 (tankgun) idle/cooling
#   Weapon 10 (artillery) idle/cooling
#   Weapon 11 (drone) idle/cooling
#   Weapon 12 (missile) idle/cooling
#   Weapon 13 (antitankrocket) idle/cooling
#   Weapon 14 (tankgun) idle/cooling
#   Target 0 (truck): HP=150.00, dist=684686.00
#   Target 1 (tank): HP=400.00, dist=652159.67
#   Target 2 (commandcenter): HP=300.70, dist=530867.00
#   Target 3 (infantry): HP=100.00, dist=775123.33
#   Target 4 (truck): HP=150.00, dist=581336.00
#   Target 5 (tank): Neutralized
#   Target 6 (commandcenter): HP=51.80, dist=519228.00
#   Target 7 (infantry): Neutralized
#   Target 8 (truck): Neutralized
#   Target 9 (tank): Neutralized
#   Target 10 (commandcenter): Neutralized
#   Target 11 (infantry): HP=100.00, dist=659264.33
#
# --- Round 25 ---
#   Weapon 0 (artillery) → Target 6 (commandcenter) | Damage: 38.61 | HP left: 13.19
#   Weapon 1 (drone) → Target 6 (commandcenter) | Damage: 21.15 | HP left: 0.00
#   Weapon 2 (missile) → Target 6 (commandcenter) | Damage: 23.24 | HP left: 0.00
#   Weapon 3 (antitankrocket) idle/cooling
#   Weapon 4 (tankgun) idle/cooling
#   Weapon 5 (artillery) → Target 2 (commandcenter) | Damage: 37.01 | HP left: 263.70
#   Weapon 6 (drone) → Target 2 (commandcenter) | Damage: 20.51 | HP left: 243.19
#   Weapon 7 (missile) → Target 2 (commandcenter) | Damage: 21.75 | HP left: 221.44
#   Weapon 8 (antitankrocket) idle/cooling
#   Weapon 9 (tankgun) idle/cooling
#   Weapon 10 (artillery) → Target 4 (truck) | Damage: 30.07 | HP left: 119.93
#   Weapon 11 (drone) → Target 4 (truck) | Damage: 17.70 | HP left: 102.23
#   Weapon 12 (missile) → Target 4 (truck) | Damage: 15.26 | HP left: 86.97
#   Weapon 13 (antitankrocket) idle/cooling
#   Weapon 14 (tankgun) idle/cooling
#   Target 0 (truck): HP=150.00, dist=684669.33
#   Target 1 (tank): HP=400.00, dist=652145.78
#   Target 2 (commandcenter): HP=221.44, dist=530867.00
#   Target 3 (infantry): HP=100.00, dist=775103.89
#   Target 4 (truck): HP=86.97, dist=581319.33
#   Target 5 (tank): Neutralized
#   Target 6 (commandcenter): Neutralized
#   Target 7 (infantry): Neutralized
#   Target 8 (truck): Neutralized
#   Target 9 (tank): Neutralized
#   Target 10 (commandcenter): Neutralized
#   Target 11 (infantry): HP=100.00, dist=659244.89
#
# --- Round 26 ---
#   Weapon 0 (artillery) idle/cooling
#   Weapon 1 (drone) idle/cooling
#   Weapon 2 (missile) idle/cooling
#   Weapon 3 (antitankrocket) idle/cooling
#   Weapon 4 (tankgun) idle/cooling
#   Weapon 5 (artillery) idle/cooling
#   Weapon 6 (drone) idle/cooling
#   Weapon 7 (missile) idle/cooling
#   Weapon 8 (antitankrocket) idle/cooling
#   Weapon 9 (tankgun) idle/cooling
#   Weapon 10 (artillery) idle/cooling
#   Weapon 11 (drone) idle/cooling
#   Weapon 12 (missile) idle/cooling
#   Weapon 13 (antitankrocket) idle/cooling
#   Weapon 14 (tankgun) idle/cooling
#   Target 0 (truck): HP=150.00, dist=684652.67
#   Target 1 (tank): HP=400.00, dist=652131.89
#   Target 2 (commandcenter): HP=221.44, dist=530867.00
#   Target 3 (infantry): HP=100.00, dist=775084.44
#   Target 4 (truck): HP=86.97, dist=581302.67
#   Target 5 (tank): Neutralized
#   Target 6 (commandcenter): Neutralized
#   Target 7 (infantry): Neutralized
#   Target 8 (truck): Neutralized
#   Target 9 (tank): Neutralized
#   Target 10 (commandcenter): Neutralized
#   Target 11 (infantry): HP=100.00, dist=659225.44
#
# --- Round 27 ---
#   Weapon 0 (artillery) idle/cooling
#   Weapon 1 (drone) → Target 2 (commandcenter) | Damage: 20.51 | HP left: 200.94
#   Weapon 2 (missile) idle/cooling
#   Weapon 3 (antitankrocket) idle/cooling
#   Weapon 4 (tankgun) idle/cooling
#   Weapon 5 (artillery) idle/cooling
#   Weapon 6 (drone) → Target 2 (commandcenter) | Damage: 20.51 | HP left: 180.43
#   Weapon 7 (missile) idle/cooling
#   Weapon 8 (antitankrocket) idle/cooling
#   Weapon 9 (tankgun) idle/cooling
#   Weapon 10 (artillery) idle/cooling
#   Weapon 11 (drone) → Target 2 (commandcenter) | Damage: 20.51 | HP left: 159.92
#   Weapon 12 (missile) idle/cooling
#   Weapon 13 (antitankrocket) idle/cooling
#   Weapon 14 (tankgun) idle/cooling
#   Target 0 (truck): HP=150.00, dist=684636.00
#   Target 1 (tank): HP=400.00, dist=652118.00
#   Target 2 (commandcenter): HP=159.92, dist=530867.00
#   Target 3 (infantry): HP=100.00, dist=775065.00
#   Target 4 (truck): HP=86.97, dist=581286.00
#   Target 5 (tank): Neutralized
#   Target 6 (commandcenter): Neutralized
#   Target 7 (infantry): Neutralized
#   Target 8 (truck): Neutralized
#   Target 9 (tank): Neutralized
#   Target 10 (commandcenter): Neutralized
#   Target 11 (infantry): HP=100.00, dist=659206.00
#
# --- Round 28 ---
#   Weapon 0 (artillery) idle/cooling
#   Weapon 1 (drone) idle/cooling
#   Weapon 2 (missile) → Target 2 (commandcenter) | Damage: 21.75 | HP left: 138.17
#   Weapon 3 (antitankrocket) idle/cooling
#   Weapon 4 (tankgun) idle/cooling
#   Weapon 5 (artillery) idle/cooling
#   Weapon 6 (drone) idle/cooling
#   Weapon 7 (missile) → Target 2 (commandcenter) | Damage: 21.75 | HP left: 116.43
#   Weapon 8 (antitankrocket) idle/cooling
#   Weapon 9 (tankgun) idle/cooling
#   Weapon 10 (artillery) idle/cooling
#   Weapon 11 (drone) idle/cooling
#   Weapon 12 (missile) → Target 2 (commandcenter) | Damage: 21.75 | HP left: 94.68
#   Weapon 13 (antitankrocket) idle/cooling
#   Weapon 14 (tankgun) idle/cooling
#   Target 0 (truck): HP=150.00, dist=684619.33
#   Target 1 (tank): HP=400.00, dist=652104.11
#   Target 2 (commandcenter): HP=94.68, dist=530867.00
#   Target 3 (infantry): HP=100.00, dist=775045.56
#   Target 4 (truck): HP=86.97, dist=581269.33
#   Target 5 (tank): Neutralized
#   Target 6 (commandcenter): Neutralized
#   Target 7 (infantry): Neutralized
#   Target 8 (truck): Neutralized
#   Target 9 (tank): Neutralized
#   Target 10 (commandcenter): Neutralized
#   Target 11 (infantry): HP=100.00, dist=659186.56
#
# --- Round 29 ---
#   Weapon 0 (artillery) → Target 2 (commandcenter) | Damage: 37.01 | HP left: 57.68
#   Weapon 1 (drone) → Target 2 (commandcenter) | Damage: 20.51 | HP left: 37.17
#   Weapon 2 (missile) idle/cooling
#   Weapon 3 (antitankrocket) idle/cooling
#   Weapon 4 (tankgun) idle/cooling
#   Weapon 5 (artillery) → Target 2 (commandcenter) | Damage: 37.01 | HP left: 0.16
#   Weapon 6 (drone) → Target 4 (truck) | Damage: 17.71 | HP left: 69.26
#   Weapon 7 (missile) idle/cooling
#   Weapon 8 (antitankrocket) idle/cooling
#   Weapon 9 (tankgun) idle/cooling
#   Weapon 10 (artillery) → Target 4 (truck) | Damage: 30.08 | HP left: 39.18
#   Weapon 11 (drone) → Target 4 (truck) | Damage: 17.71 | HP left: 21.47
#   Weapon 12 (missile) idle/cooling
#   Weapon 13 (antitankrocket) idle/cooling
#   Weapon 14 (tankgun) idle/cooling
#   Target 0 (truck): HP=150.00, dist=684602.67
#   Target 1 (tank): HP=400.00, dist=652090.22
#   Target 2 (commandcenter): HP=0.16, dist=530867.00
#   Target 3 (infantry): HP=100.00, dist=775026.11
#   Target 4 (truck): HP=21.47, dist=581252.67
#   Target 5 (tank): Neutralized
#   Target 6 (commandcenter): Neutralized
#   Target 7 (infantry): Neutralized
#   Target 8 (truck): Neutralized
#   Target 9 (tank): Neutralized
#   Target 10 (commandcenter): Neutralized
#   Target 11 (infantry): HP=100.00, dist=659167.11
#
# --- Round 30 ---
#   Weapon 0 (artillery) idle/cooling
#   Weapon 1 (drone) idle/cooling
#   Weapon 2 (missile) idle/cooling
#   Weapon 3 (antitankrocket) idle/cooling
#   Weapon 4 (tankgun) idle/cooling
#   Weapon 5 (artillery) idle/cooling
#   Weapon 6 (drone) idle/cooling
#   Weapon 7 (missile) idle/cooling
#   Weapon 8 (antitankrocket) idle/cooling
#   Weapon 9 (tankgun) idle/cooling
#   Weapon 10 (artillery) idle/cooling
#   Weapon 11 (drone) idle/cooling
#   Weapon 12 (missile) idle/cooling
#   Weapon 13 (antitankrocket) idle/cooling
#   Weapon 14 (tankgun) idle/cooling
#   Target 0 (truck): HP=150.00, dist=684586.00
#   Target 1 (tank): HP=400.00, dist=652076.33
#   Target 2 (commandcenter): HP=0.16, dist=530867.00
#   Target 3 (infantry): HP=100.00, dist=775006.67
#   Target 4 (truck): HP=21.47, dist=581236.00
#   Target 5 (tank): Neutralized
#   Target 6 (commandcenter): Neutralized
#   Target 7 (infantry): Neutralized
#   Target 8 (truck): Neutralized
#   Target 9 (tank): Neutralized
#   Target 10 (commandcenter): Neutralized
#   Target 11 (infantry): HP=100.00, dist=659147.67
#
# --- Round 31 ---
#   Weapon 0 (artillery) idle/cooling
#   Weapon 1 (drone) → Target 2 (commandcenter) | Damage: 20.51 | HP left: 0.00
#   Weapon 2 (missile) → Target 2 (commandcenter) | Damage: 21.75 | HP left: 0.00
#   Weapon 3 (antitankrocket) idle/cooling
#   Weapon 4 (tankgun) idle/cooling
#   Weapon 5 (artillery) idle/cooling
#   Weapon 6 (drone) → Target 2 (commandcenter) | Damage: 20.51 | HP left: 0.00
#   Weapon 7 (missile) → Target 4 (truck) | Damage: 15.27 | HP left: 6.20
#   Weapon 8 (antitankrocket) idle/cooling
#   Weapon 9 (tankgun) idle/cooling
#   Weapon 10 (artillery) idle/cooling
#   Weapon 11 (drone) → Target 4 (truck) | Damage: 17.71 | HP left: 0.00
#   Weapon 12 (missile) → Target 4 (truck) | Damage: 15.27 | HP left: 0.00
#   Weapon 13 (antitankrocket) idle/cooling
#   Weapon 14 (tankgun) idle/cooling
#   Target 0 (truck): HP=150.00, dist=684569.33
#   Target 1 (tank): HP=400.00, dist=652062.44
#   Target 2 (commandcenter): Neutralized
#   Target 3 (infantry): HP=100.00, dist=774987.22
#   Target 4 (truck): Neutralized
#   Target 5 (tank): Neutralized
#   Target 6 (commandcenter): Neutralized
#   Target 7 (infantry): Neutralized
#   Target 8 (truck): Neutralized
#   Target 9 (tank): Neutralized
#   Target 10 (commandcenter): Neutralized
#   Target 11 (infantry): HP=100.00, dist=659128.22
#
# --- Round 32 ---
#   Weapon 0 (artillery) idle/cooling
#   Weapon 1 (drone) idle/cooling
#   Weapon 2 (missile) idle/cooling
#   Weapon 3 (antitankrocket) idle/cooling
#   Weapon 4 (tankgun) idle/cooling
#   Weapon 5 (artillery) idle/cooling
#   Weapon 6 (drone) idle/cooling
#   Weapon 7 (missile) idle/cooling
#   Weapon 8 (antitankrocket) idle/cooling
#   Weapon 9 (tankgun) idle/cooling
#   Weapon 10 (artillery) idle/cooling
#   Weapon 11 (drone) idle/cooling
#   Weapon 12 (missile) idle/cooling
#   Weapon 13 (antitankrocket) idle/cooling
#   Weapon 14 (tankgun) idle/cooling
#   Target 0 (truck): HP=150.00, dist=684552.67
#   Target 1 (tank): HP=400.00, dist=652048.56
#   Target 2 (commandcenter): Neutralized
#   Target 3 (infantry): HP=100.00, dist=774967.78
#   Target 4 (truck): Neutralized
#   Target 5 (tank): Neutralized
#   Target 6 (commandcenter): Neutralized
#   Target 7 (infantry): Neutralized
#   Target 8 (truck): Neutralized
#   Target 9 (tank): Neutralized
#   Target 10 (commandcenter): Neutralized
#   Target 11 (infantry): HP=100.00, dist=659108.78
#
# --- Round 33 ---
#   Weapon 0 (artillery) → Target 1 (tank) | Damage: 20.35 | HP left: 379.65
#   Weapon 1 (drone) → Target 1 (tank) | Damage: 13.78 | HP left: 365.88
#   Weapon 2 (missile) idle/cooling
#   Weapon 3 (antitankrocket) idle/cooling
#   Weapon 4 (tankgun) idle/cooling
#   Weapon 5 (artillery) → Target 1 (tank) | Damage: 20.35 | HP left: 345.53
#   Weapon 6 (drone) → Target 11 (infantry) | Damage: 13.38 | HP left: 86.62
#   Weapon 7 (missile) idle/cooling
#   Weapon 8 (antitankrocket) idle/cooling
#   Weapon 9 (tankgun) idle/cooling
#   Weapon 10 (artillery) → Target 11 (infantry) | Damage: 19.38 | HP left: 67.24
#   Weapon 11 (drone) → Target 11 (infantry) | Damage: 13.38 | HP left: 53.86
#   Weapon 12 (missile) idle/cooling
#   Weapon 13 (antitankrocket) idle/cooling
#   Weapon 14 (tankgun) idle/cooling
#   Target 0 (truck): HP=150.00, dist=684536.00
#   Target 1 (tank): HP=345.53, dist=652034.67
#   Target 2 (commandcenter): Neutralized
#   Target 3 (infantry): HP=100.00, dist=774948.33
#   Target 4 (truck): Neutralized
#   Target 5 (tank): Neutralized
#   Target 6 (commandcenter): Neutralized
#   Target 7 (infantry): Neutralized
#   Target 8 (truck): Neutralized
#   Target 9 (tank): Neutralized
#   Target 10 (commandcenter): Neutralized
#   Target 11 (infantry): HP=53.86, dist=659089.33
#
# --- Round 34 ---
#   Weapon 0 (artillery) idle/cooling
#   Weapon 1 (drone) idle/cooling
#   Weapon 2 (missile) → Target 1 (tank) | Damage: 9.00 | HP left: 336.53
#   Weapon 3 (antitankrocket) idle/cooling
#   Weapon 4 (tankgun) idle/cooling
#   Weapon 5 (artillery) idle/cooling
#   Weapon 6 (drone) idle/cooling
#   Weapon 7 (missile) → Target 1 (tank) | Damage: 9.00 | HP left: 327.53
#   Weapon 8 (antitankrocket) idle/cooling
#   Weapon 9 (tankgun) idle/cooling
#   Weapon 10 (artillery) idle/cooling
#   Weapon 11 (drone) idle/cooling
#   Weapon 12 (missile) → Target 1 (tank) | Damage: 9.00 | HP left: 318.53
#   Weapon 13 (antitankrocket) idle/cooling
#   Weapon 14 (tankgun) idle/cooling
#   Target 0 (truck): HP=150.00, dist=684519.33
#   Target 1 (tank): HP=318.53, dist=652020.78
#   Target 2 (commandcenter): Neutralized
#   Target 3 (infantry): HP=100.00, dist=774928.89
#   Target 4 (truck): Neutralized
#   Target 5 (tank): Neutralized
#   Target 6 (commandcenter): Neutralized
#   Target 7 (infantry): Neutralized
#   Target 8 (truck): Neutralized
#   Target 9 (tank): Neutralized
#   Target 10 (commandcenter): Neutralized
#   Target 11 (infantry): HP=53.86, dist=659069.89
#
# --- Round 35 ---
#   Weapon 0 (artillery) idle/cooling
#   Weapon 1 (drone) → Target 1 (tank) | Damage: 13.78 | HP left: 304.76
#   Weapon 2 (missile) idle/cooling
#   Weapon 3 (antitankrocket) idle/cooling
#   Weapon 4 (tankgun) idle/cooling
#   Weapon 5 (artillery) idle/cooling
#   Weapon 6 (drone) → Target 1 (tank) | Damage: 13.78 | HP left: 290.98
#   Weapon 7 (missile) idle/cooling
#   Weapon 8 (antitankrocket) idle/cooling
#   Weapon 9 (tankgun) idle/cooling
#   Weapon 10 (artillery) idle/cooling
#   Weapon 11 (drone) → Target 1 (tank) | Damage: 13.78 | HP left: 277.20
#   Weapon 12 (missile) idle/cooling
#   Weapon 13 (antitankrocket) idle/cooling
#   Weapon 14 (tankgun) idle/cooling
#   Target 0 (truck): HP=150.00, dist=684502.67
#   Target 1 (tank): HP=277.20, dist=652006.89
#   Target 2 (commandcenter): Neutralized
#   Target 3 (infantry): HP=100.00, dist=774909.44
#   Target 4 (truck): Neutralized
#   Target 5 (tank): Neutralized
#   Target 6 (commandcenter): Neutralized
#   Target 7 (infantry): Neutralized
#   Target 8 (truck): Neutralized
#   Target 9 (tank): Neutralized
#   Target 10 (commandcenter): Neutralized
#   Target 11 (infantry): HP=53.86, dist=659050.44
#
# --- Round 36 ---
#   Weapon 0 (artillery) idle/cooling
#   Weapon 1 (drone) idle/cooling
#   Weapon 2 (missile) idle/cooling
#   Weapon 3 (antitankrocket) idle/cooling
#   Weapon 4 (tankgun) idle/cooling
#   Weapon 5 (artillery) idle/cooling
#   Weapon 6 (drone) idle/cooling
#   Weapon 7 (missile) idle/cooling
#   Weapon 8 (antitankrocket) idle/cooling
#   Weapon 9 (tankgun) idle/cooling
#   Weapon 10 (artillery) idle/cooling
#   Weapon 11 (drone) idle/cooling
#   Weapon 12 (missile) idle/cooling
#   Weapon 13 (antitankrocket) idle/cooling
#   Weapon 14 (tankgun) idle/cooling
#   Target 0 (truck): HP=150.00, dist=684486.00
#   Target 1 (tank): HP=277.20, dist=651993.00
#   Target 2 (commandcenter): Neutralized
#   Target 3 (infantry): HP=100.00, dist=774890.00
#   Target 4 (truck): Neutralized
#   Target 5 (tank): Neutralized
#   Target 6 (commandcenter): Neutralized
#   Target 7 (infantry): Neutralized
#   Target 8 (truck): Neutralized
#   Target 9 (tank): Neutralized
#   Target 10 (commandcenter): Neutralized
#   Target 11 (infantry): HP=53.86, dist=659031.00
#
# --- Round 37 ---
#   Weapon 0 (artillery) → Target 1 (tank) | Damage: 20.35 | HP left: 256.85
#   Weapon 1 (drone) → Target 1 (tank) | Damage: 13.78 | HP left: 243.07
#   Weapon 2 (missile) → Target 1 (tank) | Damage: 9.00 | HP left: 234.07
#   Weapon 3 (antitankrocket) idle/cooling
#   Weapon 4 (tankgun) idle/cooling
#   Weapon 5 (artillery) → Target 11 (infantry) | Damage: 19.39 | HP left: 34.47
#   Weapon 6 (drone) → Target 11 (infantry) | Damage: 13.39 | HP left: 21.08
#   Weapon 7 (missile) → Target 11 (infantry) | Damage: 9.00 | HP left: 12.08
#   Weapon 8 (antitankrocket) idle/cooling
#   Weapon 9 (tankgun) idle/cooling
#   Weapon 10 (artillery) → Target 0 (truck) | Damage: 15.89 | HP left: 134.11
#   Weapon 11 (drone) → Target 0 (truck) | Damage: 11.97 | HP left: 122.14
#   Weapon 12 (missile) → Target 0 (truck) | Damage: 9.00 | HP left: 113.14
#   Weapon 13 (antitankrocket) idle/cooling
#   Weapon 14 (tankgun) idle/cooling
#   Target 0 (truck): HP=113.14, dist=684469.33
#   Target 1 (tank): HP=234.07, dist=651979.11
#   Target 2 (commandcenter): Neutralized
#   Target 3 (infantry): HP=100.00, dist=774870.56
#   Target 4 (truck): Neutralized
#   Target 5 (tank): Neutralized
#   Target 6 (commandcenter): Neutralized
#   Target 7 (infantry): Neutralized
#   Target 8 (truck): Neutralized
#   Target 9 (tank): Neutralized
#   Target 10 (commandcenter): Neutralized
#   Target 11 (infantry): HP=12.08, dist=659011.56
#
# --- Round 38 ---
#   Weapon 0 (artillery) idle/cooling
#   Weapon 1 (drone) idle/cooling
#   Weapon 2 (missile) idle/cooling
#   Weapon 3 (antitankrocket) idle/cooling
#   Weapon 4 (tankgun) idle/cooling
#   Weapon 5 (artillery) idle/cooling
#   Weapon 6 (drone) idle/cooling
#   Weapon 7 (missile) idle/cooling
#   Weapon 8 (antitankrocket) idle/cooling
#   Weapon 9 (tankgun) idle/cooling
#   Weapon 10 (artillery) idle/cooling
#   Weapon 11 (drone) idle/cooling
#   Weapon 12 (missile) idle/cooling
#   Weapon 13 (antitankrocket) idle/cooling
#   Weapon 14 (tankgun) idle/cooling
#   Target 0 (truck): HP=113.14, dist=684452.67
#   Target 1 (tank): HP=234.07, dist=651965.22
#   Target 2 (commandcenter): Neutralized
#   Target 3 (infantry): HP=100.00, dist=774851.11
#   Target 4 (truck): Neutralized
#   Target 5 (tank): Neutralized
#   Target 6 (commandcenter): Neutralized
#   Target 7 (infantry): Neutralized
#   Target 8 (truck): Neutralized
#   Target 9 (tank): Neutralized
#   Target 10 (commandcenter): Neutralized
#   Target 11 (infantry): HP=12.08, dist=658992.11
#
# --- Round 39 ---
#   Weapon 0 (artillery) idle/cooling
#   Weapon 1 (drone) → Target 1 (tank) | Damage: 13.78 | HP left: 220.29
#   Weapon 2 (missile) idle/cooling
#   Weapon 3 (antitankrocket) idle/cooling
#   Weapon 4 (tankgun) idle/cooling
#   Weapon 5 (artillery) idle/cooling
#   Weapon 6 (drone) → Target 1 (tank) | Damage: 13.78 | HP left: 206.51
#   Weapon 7 (missile) idle/cooling
#   Weapon 8 (antitankrocket) idle/cooling
#   Weapon 9 (tankgun) idle/cooling
#   Weapon 10 (artillery) idle/cooling
#   Weapon 11 (drone) → Target 1 (tank) | Damage: 13.78 | HP left: 192.73
#   Weapon 12 (missile) idle/cooling
#   Weapon 13 (antitankrocket) idle/cooling
#   Weapon 14 (tankgun) idle/cooling
#   Target 0 (truck): HP=113.14, dist=684436.00
#   Target 1 (tank): HP=192.73, dist=651951.33
#   Target 2 (commandcenter): Neutralized
#   Target 3 (infantry): HP=100.00, dist=774831.67
#   Target 4 (truck): Neutralized
#   Target 5 (tank): Neutralized
#   Target 6 (commandcenter): Neutralized
#   Target 7 (infantry): Neutralized
#   Target 8 (truck): Neutralized
#   Target 9 (tank): Neutralized
#   Target 10 (commandcenter): Neutralized
#   Target 11 (infantry): HP=12.08, dist=658972.67
#
# --- Round 40 ---
#   Weapon 0 (artillery) idle/cooling
#   Weapon 1 (drone) idle/cooling
#   Weapon 2 (missile) → Target 1 (tank) | Damage: 9.00 | HP left: 183.73
#   Weapon 3 (antitankrocket) idle/cooling
#   Weapon 4 (tankgun) idle/cooling
#   Weapon 5 (artillery) idle/cooling
#   Weapon 6 (drone) idle/cooling
# ...
#   Target 1 (tank): HP=165.73, dist=651937.44
#   Target 2 (commandcenter): Neutralized
#   Target 3 (infantry): HP=100.00, dist=774812.22
#   Target 4 (truck): Neutralized
#   Target 5 (tank): Neutralized
#   Target 6 (commandcenter): Neutralized
#   Target 7 (infantry): Neutralized
#   Target 8 (truck): Neutralized
#   Target 9 (tank): Neutralized
#   Target 10 (commandcenter): Neutralized
#   Target 11 (infantry): HP=12.08, dist=658953.22
#
# --- Round 41 ---
#   Weapon 0 (artillery) → Target 1 (tank) | Damage: 20.36 | HP left: 145.37
#   Weapon 1 (drone) → Target 1 (tank) | Damage: 13.78 | HP left: 131.59
#   Weapon 2 (missile) idle/cooling
#   Weapon 3 (antitankrocket) idle/cooling
#   Weapon 4 (tankgun) idle/cooling
#   Weapon 5 (artillery) → Target 1 (tank) | Damage: 20.36 | HP left: 111.23
#   Weapon 6 (drone) → Target 11 (infantry) | Damage: 13.39 | HP left: 0.00
#   Weapon 7 (missile) idle/cooling
#   Weapon 8 (antitankrocket) idle/cooling
#   Weapon 9 (tankgun) idle/cooling
#   Weapon 10 (artillery) → Target 11 (infantry) | Damage: 19.40 | HP left: 0.00
#   Weapon 11 (drone) → Target 11 (infantry) | Damage: 13.39 | HP left: 0.00
#   Weapon 12 (missile) idle/cooling
#   Weapon 13 (antitankrocket) idle/cooling
#   Weapon 14 (tankgun) idle/cooling
#   Target 0 (truck): HP=113.14, dist=684402.67
#   Target 1 (tank): HP=111.23, dist=651923.56
#   Target 2 (commandcenter): Neutralized
#   Target 3 (infantry): HP=100.00, dist=774792.78
#   Target 4 (truck): Neutralized
#   Target 5 (tank): Neutralized
#   Target 6 (commandcenter): Neutralized
#   Target 7 (infantry): Neutralized
#   Target 8 (truck): Neutralized
#   Target 9 (tank): Neutralized
#   Target 10 (commandcenter): Neutralized
#   Target 11 (infantry): Neutralized
#
# --- Round 42 ---
#   Weapon 0 (artillery) idle/cooling
#   Weapon 1 (drone) idle/cooling
#   Weapon 2 (missile) idle/cooling
#   Weapon 3 (antitankrocket) idle/cooling
#   Weapon 4 (tankgun) idle/cooling
#   Weapon 5 (artillery) idle/cooling
#   Weapon 6 (drone) idle/cooling
#   Weapon 7 (missile) idle/cooling
#   Weapon 8 (antitankrocket) idle/cooling
#   Weapon 9 (tankgun) idle/cooling
#   Weapon 10 (artillery) idle/cooling
#   Weapon 11 (drone) idle/cooling
#   Weapon 12 (missile) idle/cooling
#   Weapon 13 (antitankrocket) idle/cooling
#   Weapon 14 (tankgun) idle/cooling
#   Target 0 (truck): HP=113.14, dist=684386.00
#   Target 1 (tank): HP=111.23, dist=651909.67
#   Target 2 (commandcenter): Neutralized
#   Target 3 (infantry): HP=100.00, dist=774773.33
#   Target 4 (truck): Neutralized
#   Target 5 (tank): Neutralized
#   Target 6 (commandcenter): Neutralized
#   Target 7 (infantry): Neutralized
#   Target 8 (truck): Neutralized
#   Target 9 (tank): Neutralized
#   Target 10 (commandcenter): Neutralized
#   Target 11 (infantry): Neutralized
#
# --- Round 43 ---
#   Weapon 0 (artillery) idle/cooling
#   Weapon 1 (drone) → Target 1 (tank) | Damage: 13.78 | HP left: 97.44
#   Weapon 2 (missile) → Target 1 (tank) | Damage: 9.00 | HP left: 88.44
#   Weapon 3 (antitankrocket) idle/cooling
#   Weapon 4 (tankgun) idle/cooling
#   Weapon 5 (artillery) idle/cooling
#   Weapon 6 (drone) → Target 1 (tank) | Damage: 13.78 | HP left: 74.66
#   Weapon 7 (missile) → Target 0 (truck) | Damage: 9.00 | HP left: 104.14
#   Weapon 8 (antitankrocket) idle/cooling
#   Weapon 9 (tankgun) idle/cooling
#   Weapon 10 (artillery) idle/cooling
#   Weapon 11 (drone) → Target 0 (truck) | Damage: 11.98 | HP left: 92.16
#   Weapon 12 (missile) → Target 0 (truck) | Damage: 9.00 | HP left: 83.16
#   Weapon 13 (antitankrocket) idle/cooling
#   Weapon 14 (tankgun) idle/cooling
#   Target 0 (truck): HP=83.16, dist=684369.33
#   Target 1 (tank): HP=74.66, dist=651895.78
#   Target 2 (commandcenter): Neutralized
#   Target 3 (infantry): HP=100.00, dist=774753.89
#   Target 4 (truck): Neutralized
#   Target 5 (tank): Neutralized
#   Target 6 (commandcenter): Neutralized
#   Target 7 (infantry): Neutralized
#   Target 8 (truck): Neutralized
#   Target 9 (tank): Neutralized
#   Target 10 (commandcenter): Neutralized
#   Target 11 (infantry): Neutralized
#
# --- Round 44 ---
#   Weapon 0 (artillery) idle/cooling
#   Weapon 1 (drone) idle/cooling
#   Weapon 2 (missile) idle/cooling
#   Weapon 3 (antitankrocket) idle/cooling
#   Weapon 4 (tankgun) idle/cooling
#   Weapon 5 (artillery) idle/cooling
#   Weapon 6 (drone) idle/cooling
#   Weapon 7 (missile) idle/cooling
#   Weapon 8 (antitankrocket) idle/cooling
#   Weapon 9 (tankgun) idle/cooling
#   Weapon 10 (artillery) idle/cooling
#   Weapon 11 (drone) idle/cooling
#   Weapon 12 (missile) idle/cooling
#   Weapon 13 (antitankrocket) idle/cooling
#   Weapon 14 (tankgun) idle/cooling
#   Target 0 (truck): HP=83.16, dist=684352.67
#   Target 1 (tank): HP=74.66, dist=651881.89
#   Target 2 (commandcenter): Neutralized
#   Target 3 (infantry): HP=100.00, dist=774734.44
#   Target 4 (truck): Neutralized
#   Target 5 (tank): Neutralized
#   Target 6 (commandcenter): Neutralized
#   Target 7 (infantry): Neutralized
#   Target 8 (truck): Neutralized
#   Target 9 (tank): Neutralized
#   Target 10 (commandcenter): Neutralized
#   Target 11 (infantry): Neutralized
#
# --- Round 45 ---
#   Weapon 0 (artillery) → Target 1 (tank) | Damage: 20.37 | HP left: 54.29
#   Weapon 1 (drone) → Target 1 (tank) | Damage: 13.79 | HP left: 40.50
#   Weapon 2 (missile) idle/cooling
#   Weapon 3 (antitankrocket) idle/cooling
#   Weapon 4 (tankgun) idle/cooling
#   Weapon 5 (artillery) → Target 1 (tank) | Damage: 20.37 | HP left: 20.14
#   Weapon 6 (drone) → Target 0 (truck) | Damage: 11.98 | HP left: 71.18
#   Weapon 7 (missile) idle/cooling
#   Weapon 8 (antitankrocket) idle/cooling
#   Weapon 9 (tankgun) idle/cooling
#   Weapon 10 (artillery) → Target 0 (truck) | Damage: 15.90 | HP left: 55.28
#   Weapon 11 (drone) → Target 0 (truck) | Damage: 11.98 | HP left: 43.29
#   Weapon 12 (missile) idle/cooling
#   Weapon 13 (antitankrocket) idle/cooling
#   Weapon 14 (tankgun) idle/cooling
#   Target 0 (truck): HP=43.29, dist=684336.00
#   Target 1 (tank): HP=20.14, dist=651868.00
#   Target 2 (commandcenter): Neutralized
#   Target 3 (infantry): HP=100.00, dist=774715.00
#   Target 4 (truck): Neutralized
#   Target 5 (tank): Neutralized
#   Target 6 (commandcenter): Neutralized
#   Target 7 (infantry): Neutralized
#   Target 8 (truck): Neutralized
#   Target 9 (tank): Neutralized
#   Target 10 (commandcenter): Neutralized
#   Target 11 (infantry): Neutralized
#
# --- Round 46 ---
#   Weapon 0 (artillery) idle/cooling
#   Weapon 1 (drone) idle/cooling
#   Weapon 2 (missile) → Target 1 (tank) | Damage: 9.00 | HP left: 11.14
#   Weapon 3 (antitankrocket) idle/cooling
#   Weapon 4 (tankgun) idle/cooling
#   Weapon 5 (artillery) idle/cooling
#   Weapon 6 (drone) idle/cooling
#   Weapon 7 (missile) → Target 1 (tank) | Damage: 9.00 | HP left: 2.14
#   Weapon 8 (antitankrocket) idle/cooling
#   Weapon 9 (tankgun) idle/cooling
#   Weapon 10 (artillery) idle/cooling
#   Weapon 11 (drone) idle/cooling
#   Weapon 12 (missile) → Target 1 (tank) | Damage: 9.00 | HP left: 0.00
#   Weapon 13 (antitankrocket) idle/cooling
#   Weapon 14 (tankgun) idle/cooling
#   Target 0 (truck): HP=43.29, dist=684319.33
#   Target 1 (tank): Neutralized
#   Target 2 (commandcenter): Neutralized
#   Target 3 (infantry): HP=100.00, dist=774695.56
#   Target 4 (truck): Neutralized
#   Target 5 (tank): Neutralized
#   Target 6 (commandcenter): Neutralized
#   Target 7 (infantry): Neutralized
#   Target 8 (truck): Neutralized
#   Target 9 (tank): Neutralized
#   Target 10 (commandcenter): Neutralized
#   Target 11 (infantry): Neutralized
#
# --- Round 47 ---
#   Weapon 0 (artillery) idle/cooling
#   Weapon 1 (drone) → Target 0 (truck) | Damage: 11.98 | HP left: 31.31
#   Weapon 2 (missile) idle/cooling
#   Weapon 3 (antitankrocket) idle/cooling
#   Weapon 4 (tankgun) idle/cooling
#   Weapon 5 (artillery) idle/cooling
#   Weapon 6 (drone) → Target 0 (truck) | Damage: 11.98 | HP left: 19.33
#   Weapon 7 (missile) idle/cooling
#   Weapon 8 (antitankrocket) idle/cooling
#   Weapon 9 (tankgun) idle/cooling
#   Weapon 10 (artillery) idle/cooling
#   Weapon 11 (drone) → Target 0 (truck) | Damage: 11.98 | HP left: 7.35
#   Weapon 12 (missile) idle/cooling
#   Weapon 13 (antitankrocket) idle/cooling
#   Weapon 14 (tankgun) idle/cooling
#   Target 0 (truck): HP=7.35, dist=684302.67
#   Target 1 (tank): Neutralized
#   Target 2 (commandcenter): Neutralized
#   Target 3 (infantry): HP=100.00, dist=774676.11
#   Target 4 (truck): Neutralized
#   Target 5 (tank): Neutralized
#   Target 6 (commandcenter): Neutralized
#   Target 7 (infantry): Neutralized
#   Target 8 (truck): Neutralized
#   Target 9 (tank): Neutralized
#   Target 10 (commandcenter): Neutralized
#   Target 11 (infantry): Neutralized
#
# --- Round 48 ---
#   Weapon 0 (artillery) idle/cooling
#   Weapon 1 (drone) idle/cooling
#   Weapon 2 (missile) idle/cooling
#   Weapon 3 (antitankrocket) idle/cooling
#   Weapon 4 (tankgun) idle/cooling
#   Weapon 5 (artillery) idle/cooling
#   Weapon 6 (drone) idle/cooling
#   Weapon 7 (missile) idle/cooling
#   Weapon 8 (antitankrocket) idle/cooling
#   Weapon 9 (tankgun) idle/cooling
#   Weapon 10 (artillery) idle/cooling
#   Weapon 11 (drone) idle/cooling
#   Weapon 12 (missile) idle/cooling
#   Weapon 13 (antitankrocket) idle/cooling
#   Weapon 14 (tankgun) idle/cooling
#   Target 0 (truck): HP=7.35, dist=684286.00
#   Target 1 (tank): Neutralized
#   Target 2 (commandcenter): Neutralized
#   Target 3 (infantry): HP=100.00, dist=774656.67
#   Target 4 (truck): Neutralized
#   Target 5 (tank): Neutralized
#   Target 6 (commandcenter): Neutralized
#   Target 7 (infantry): Neutralized
#   Target 8 (truck): Neutralized
#   Target 9 (tank): Neutralized
#   Target 10 (commandcenter): Neutralized
#   Target 11 (infantry): Neutralized
#
# --- Round 49 ---
#   Weapon 0 (artillery) → Target 0 (truck) | Damage: 15.91 | HP left: 0.00
#   Weapon 1 (drone) → Target 0 (truck) | Damage: 11.99 | HP left: 0.00
#   Weapon 2 (missile) → Target 0 (truck) | Damage: 9.00 | HP left: 0.00
#   Weapon 3 (antitankrocket) idle/cooling
#   Weapon 4 (tankgun) idle/cooling
#   Weapon 5 (artillery) → Target 3 (infantry) | Damage: 11.00 | HP left: 89.00
#   Weapon 6 (drone) → Target 3 (infantry) | Damage: 6.96 | HP left: 82.04
#   Weapon 7 (missile) idle/cooling
#   Weapon 8 (antitankrocket) idle/cooling
#   Weapon 9 (tankgun) idle/cooling
#   Weapon 10 (artillery) → Target 3 (infantry) | Damage: 11.00 | HP left: 71.04
#   Weapon 11 (drone) idle/cooling
#   Weapon 12 (missile) idle/cooling
#   Weapon 13 (antitankrocket) idle/cooling
#   Weapon 14 (tankgun) idle/cooling
#   Target 0 (truck): Neutralized
#   Target 1 (tank): Neutralized
#   Target 2 (commandcenter): Neutralized
#   Target 3 (infantry): HP=71.04, dist=774637.22
#   Target 4 (truck): Neutralized
#   Target 5 (tank): Neutralized
#   Target 6 (commandcenter): Neutralized
#   Target 7 (infantry): Neutralized
#   Target 8 (truck): Neutralized
#   Target 9 (tank): Neutralized
#   Target 10 (commandcenter): Neutralized
#   Target 11 (infantry): Neutralized
#
# --- Round 50 ---
#   Weapon 0 (artillery) idle/cooling
#   Weapon 1 (drone) idle/cooling
#   Weapon 2 (missile) idle/cooling
#   Weapon 3 (antitankrocket) idle/cooling
#   Weapon 4 (tankgun) idle/cooling
#   Weapon 5 (artillery) idle/cooling
#   Weapon 6 (drone) idle/cooling
#   Weapon 7 (missile) idle/cooling
#   Weapon 8 (antitankrocket) idle/cooling
#   Weapon 9 (tankgun) idle/cooling
#   Weapon 10 (artillery) idle/cooling
#   Weapon 11 (drone) → Target 3 (infantry) | Damage: 6.97 | HP left: 64.07
#   Weapon 12 (missile) idle/cooling
#   Weapon 13 (antitankrocket) idle/cooling
#   Weapon 14 (tankgun) idle/cooling
#   Target 0 (truck): Neutralized
#   Target 1 (tank): Neutralized
#   Target 2 (commandcenter): Neutralized
#   Target 3 (infantry): HP=64.07, dist=774617.78
#   Target 4 (truck): Neutralized
#   Target 5 (tank): Neutralized
#   Target 6 (commandcenter): Neutralized
#   Target 7 (infantry): Neutralized
#   Target 8 (truck): Neutralized
#   Target 9 (tank): Neutralized
#   Target 10 (commandcenter): Neutralized
#   Target 11 (infantry): Neutralized
#
# --- Round 51 ---
#   Weapon 0 (artillery) idle/cooling
#   Weapon 1 (drone) → Target 3 (infantry) | Damage: 6.97 | HP left: 57.10
#   Weapon 2 (missile) idle/cooling
#   Weapon 3 (antitankrocket) idle/cooling
#   Weapon 4 (tankgun) idle/cooling
#   Weapon 5 (artillery) idle/cooling
#   Weapon 6 (drone) → Target 3 (infantry) | Damage: 6.97 | HP left: 50.14
#   Weapon 7 (missile) idle/cooling
#   Weapon 8 (antitankrocket) idle/cooling
#   Weapon 9 (tankgun) idle/cooling
#   Weapon 10 (artillery) idle/cooling
#   Weapon 11 (drone) idle/cooling
#   Weapon 12 (missile) idle/cooling
#   Weapon 13 (antitankrocket) idle/cooling
#   Weapon 14 (tankgun) idle/cooling
#   Target 0 (truck): Neutralized
#   Target 1 (tank): Neutralized
#   Target 2 (commandcenter): Neutralized
#   Target 3 (infantry): HP=50.14, dist=774598.33
#   Target 4 (truck): Neutralized
#   Target 5 (tank): Neutralized
#   Target 6 (commandcenter): Neutralized
#   Target 7 (infantry): Neutralized
#   Target 8 (truck): Neutralized
#   Target 9 (tank): Neutralized
#   Target 10 (commandcenter): Neutralized
#   Target 11 (infantry): Neutralized
#
# --- Round 52 ---
#   Weapon 0 (artillery) idle/cooling
#   Weapon 1 (drone) idle/cooling
#   Weapon 2 (missile) idle/cooling
#   Weapon 3 (antitankrocket) idle/cooling
#   Weapon 4 (tankgun) idle/cooling
#   Weapon 5 (artillery) idle/cooling
#   Weapon 6 (drone) idle/cooling
#   Weapon 7 (missile) idle/cooling
#   Weapon 8 (antitankrocket) idle/cooling
#   Weapon 9 (tankgun) idle/cooling
#   Weapon 10 (artillery) idle/cooling
#   Weapon 11 (drone) → Target 3 (infantry) | Damage: 6.97 | HP left: 43.17
#   Weapon 12 (missile) idle/cooling
#   Weapon 13 (antitankrocket) idle/cooling
#   Weapon 14 (tankgun) idle/cooling
#   Target 0 (truck): Neutralized
#   Target 1 (tank): Neutralized
#   Target 2 (commandcenter): Neutralized
#   Target 3 (infantry): HP=43.17, dist=774578.89
#   Target 4 (truck): Neutralized
#   Target 5 (tank): Neutralized
#   Target 6 (commandcenter): Neutralized
#   Target 7 (infantry): Neutralized
#   Target 8 (truck): Neutralized
#   Target 9 (tank): Neutralized
#   Target 10 (commandcenter): Neutralized
#   Target 11 (infantry): Neutralized
#
# --- Round 53 ---
#   Weapon 0 (artillery) → Target 3 (infantry) | Damage: 11.00 | HP left: 32.17
#   Weapon 1 (drone) → Target 3 (infantry) | Damage: 6.97 | HP left: 25.20
#   Weapon 2 (missile) idle/cooling
#   Weapon 3 (antitankrocket) idle/cooling
#   Weapon 4 (tankgun) idle/cooling
#   Weapon 5 (artillery) → Target 3 (infantry) | Damage: 11.00 | HP left: 14.20
#   Weapon 6 (drone) idle/cooling
#   Weapon 7 (missile) idle/cooling
#   Weapon 8 (antitankrocket) idle/cooling
#   Weapon 9 (tankgun) idle/cooling
#   Weapon 10 (artillery) idle/cooling
#   Weapon 11 (drone) idle/cooling
#   Weapon 12 (missile) idle/cooling
#   Weapon 13 (antitankrocket) idle/cooling
#   Weapon 14 (tankgun) idle/cooling
#   Target 0 (truck): Neutralized
#   Target 1 (tank): Neutralized
#   Target 2 (commandcenter): Neutralized
#   Target 3 (infantry): HP=14.20, dist=774559.44
#   Target 4 (truck): Neutralized
#   Target 5 (tank): Neutralized
#   Target 6 (commandcenter): Neutralized
#   Target 7 (infantry): Neutralized
#   Target 8 (truck): Neutralized
#   Target 9 (tank): Neutralized
#   Target 10 (commandcenter): Neutralized
#   Target 11 (infantry): Neutralized
#
# --- Round 54 ---
#   Weapon 0 (artillery) idle/cooling
#   Weapon 1 (drone) idle/cooling
#   Weapon 2 (missile) idle/cooling
#   Weapon 3 (antitankrocket) idle/cooling
#   Weapon 4 (tankgun) idle/cooling
#   Weapon 5 (artillery) idle/cooling
#   Weapon 6 (drone) → Target 3 (infantry) | Damage: 6.97 | HP left: 7.23
#   Weapon 7 (missile) idle/cooling
#   Weapon 8 (antitankrocket) idle/cooling
#   Weapon 9 (tankgun) idle/cooling
#   Weapon 10 (artillery) → Target 3 (infantry) | Damage: 11.00 | HP left: 0.00
#   Weapon 11 (drone) → Target 3 (infantry) | Damage: 6.97 | HP left: 0.00
#   Weapon 12 (missile) idle/cooling
#   Weapon 13 (antitankrocket) idle/cooling
#   Weapon 14 (tankgun) idle/cooling
#   Target 0 (truck): Neutralized
#   Target 1 (tank): Neutralized
#   Target 2 (commandcenter): Neutralized
#   Target 3 (infantry): Neutralized
#   Target 4 (truck): Neutralized
#   Target 5 (tank): Neutralized
#   Target 6 (commandcenter): Neutralized
#   Target 7 (infantry): Neutralized
#   Target 8 (truck): Neutralized
#   Target 9 (tank): Neutralized
#   Target 10 (commandcenter): Neutralized
#   Target 11 (infantry): Neutralized
#
# ✅ All targets neutralized in 54 rounds.
